# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import time

warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=DeprecationWarning)

# %% [markdown]
# # Train and test on real data
# ## Short range
# ### Filter

# %%
# https://api.pharmgkb.org/v1/download/submission/553247439
warfarin = pd.read_excel('PS206767-553247439.xls', sheet_name=1)

# %%
warfarin_clean = warfarin.loc[:,
                 [
                     'Gender',
                     'Race (OMB)',
                     'Age',
                     'Height (cm)',
                     'Weight (kg)',

                     'Indication for Warfarin Treatment',
                     'Diabetes',
                     'Congestive Heart Failure and/or Cardiomyopathy',
                     'Valve Replacement',
                     'Aspirin',
                     'Acetaminophen or Paracetamol (Tylenol)',
                     'Was Dose of Acetaminophen or Paracetamol (Tylenol) >1300mg/day',
                     'Simvastatin (Zocor)',
                     'Atorvastatin (Lipitor)',
                     'Fluvastatin (Lescol)',
                     'Lovastatin (Mevacor)',
                     'Pravastatin (Pravachol)',
                     'Rosuvastatin (Crestor)',
                     'Cerivastatin (Baycol)',
                     'Amiodarone (Cordarone)',
                     'Carbamazepine (Tegretol)',
                     'Phenytoin (Dilantin)',
                     'Rifampin or Rifampicin',
                     'Sulfonamide Antibiotics',
                     'Macrolide Antibiotics',
                     'Anti-fungal Azoles',
                     'Herbal Medications, Vitamins, Supplements',
                     'Current Smoker',

                     'VKORC1 -1639 consensus',
                     'VKORC1 497 consensus',
                     'VKORC1 1173 consensus',
                     'VKORC1 1542 consensus',
                     'VKORC1 3730 consensus',
                     'VKORC1 2255 consensus',
                     'VKORC1 -4451 consensus',
                     'CYP2C9 consensus',

                     'Target INR',
                     'Estimated Target INR Range Based on Indication',
                     'Therapeutic Dose of Warfarin', ]]
warfarin_clean = warfarin_clean.dropna(subset=['Height (cm)',
                                               'Weight (kg)',
                                               'Therapeutic Dose of Warfarin', ])

# %% [markdown]
# ### Transform

# %%
data = pd.DataFrame(columns=[
    'Gender',
    'Age in decades',
    'Height (cm)',
    'Weight (kg)',
    'Race Asian',
    'Race Black or African American',
    'Race Caucasian or White',
    'Race Unknown',

    'DVT',
    'PE',
    'Afib/flutter',
    'Heart Valve',
    'Cardiomyopathy/LV Dilation',
    'Stroke',
    'Post-Orthopedic',
    'Other',
    'Diabetes',
    'Congestive Heart Failure and/or Cardiomyopathy',
    'Valve Replacement',

    'Aspirin',
    'Acetaminophen or Paracetamol (Tylenol)',
    'Was Dose of Acetaminophen or Paracetamol (Tylenol) >1300mg/day',
    'Simvastatin (Zocor)',
    'Atorvastatin (Lipitor)',
    'Fluvastatin (Lescol)',
    'Lovastatin (Mevacor)',
    'Pravastatin (Pravachol)',
    'Rosuvastatin (Crestor)',
    'Cerivastatin (Baycol)',
    'Amiodarone (Cordarone)',
    'Carbamazepine (Tegretol)',
    'Phenytoin (Dilantin)',
    'Rifampin or Rifampicin',
    'Sulfonamide Antibiotics',
    'Macrolide Antibiotics',
    'Anti-fungal Azoles',
    'Herbal Medications, Vitamins, Supplements',
    'Current Smoker',

    'CYP2C9 *1',
    'CYP2C9 *2',
    'CYP2C9 *3',
    'CYP2C9 *4',
    'CYP2C9 *5',
    'CYP2C9 *6',
    'CYP2C9 *7',
    'CYP2C9 *8',
    'CYP2C9 *9',
    'CYP2C9 *10',
    'CYP2C9 *11',
    'CYP2C9 *12',
    'CYP2C9 *13',
    'CYP2C9 *14',

    'VKORC1 - -1639G>A',
    'VKORC1 - 497T>G',
    'VKORC1 - 1173C>T',
    'VKORC1 - 1542G>C',
    'VKORC1 - 3730G>A',
    'VKORC1 - 2255C>T',
    'VKORC1 - -4451C>A',

    'Target INR',
    'dose',
    'type'])

# %% [markdown]
# ### Type detail
#
# - Ngày 1 viên 1mg -> 7mg/tuần
# - Ngày 1 viên 2mg hoặc 2 viên 1mg -> 14mg/tuần
# - Ngày 1 viên 3mg -> 21mg/tuần
# - Ngày 1 viên 4mg hoặc 2 viên 2mg -> 28mg/tuần
# - Ngày 1 viên 5mg hoặc 2 viên 2.5mg -> 35mg/tuần
# - Ngày 1 viên 6mg hoặc 2 viên 3mg -> 42mg/tuần
# - Ngày 1 viên 7.5mg -> 52.5mg/tuần
# - Ngày 2 viên 4mg -> 56mg/tuần
# - Ngày 2 viên 5mg -> 70mg/tuần
# - Ngày 2 viên 6mg -> 84mg/tuần
# - Ngày 2 viên 7.5mg -> 105mg/tuần

# %%
warfarin_data = []

for index, row in warfarin_clean.iterrows():
    sample = {
        'Gender': 1 if row['Gender'] == 'male' else 0,
        'Age in decades': 0,
        'Height (cm)': row['Height (cm)'],
        'Weight (kg)': row['Weight (kg)'],

        'DVT': 0,
        'PE': 0,
        'Afib/flutter': 0,
        'Heart Valve': 0,
        'Cardiomyopathy/LV Dilation': 0,
        'Stroke': 0,
        'Post-Orthopedic': 0,
        'Other': 0,
        'Diabetes': 0 if pd.isnull(row['Diabetes']) else row['Diabetes'],
        'Congestive Heart Failure and/or Cardiomyopathy': 0 if pd.isnull(row['Congestive Heart Failure and/or Cardiomyopathy']) else row['Congestive Heart Failure and/or Cardiomyopathy'],
        'Valve Replacement': 0 if pd.isnull(row['Valve Replacement']) else row['Valve Replacement'],
        
        'Aspirin': 0 if pd.isnull(row['Aspirin']) else row['Aspirin'],
        'Acetaminophen or Paracetamol (Tylenol)': 0 if pd.isnull(row['Acetaminophen or Paracetamol (Tylenol)']) else row['Acetaminophen or Paracetamol (Tylenol)'],
        'Was Dose of Acetaminophen or Paracetamol (Tylenol) >1300mg/day': 0 if pd.isnull(row['Was Dose of Acetaminophen or Paracetamol (Tylenol) >1300mg/day']) else row['Was Dose of Acetaminophen or Paracetamol (Tylenol) >1300mg/day'],
        'Simvastatin (Zocor)': 0 if pd.isnull(row['Simvastatin (Zocor)']) else row['Simvastatin (Zocor)'],
        'Atorvastatin (Lipitor)': 0 if pd.isnull(row['Atorvastatin (Lipitor)']) else row['Atorvastatin (Lipitor)'],
        'Fluvastatin (Lescol)': 0 if pd.isnull(row['Fluvastatin (Lescol)']) else row['Fluvastatin (Lescol)'],
        'Lovastatin (Mevacor)': 0 if pd.isnull(row['Lovastatin (Mevacor)']) else row['Lovastatin (Mevacor)'],
        'Pravastatin (Pravachol)': 0 if pd.isnull(row['Pravastatin (Pravachol)']) else row['Pravastatin (Pravachol)'],
        'Rosuvastatin (Crestor)': 0 if pd.isnull(row['Rosuvastatin (Crestor)']) else row['Rosuvastatin (Crestor)'],
        'Cerivastatin (Baycol)': 0 if pd.isnull(row['Cerivastatin (Baycol)']) else row['Cerivastatin (Baycol)'],
        'Amiodarone (Cordarone)': 0 if pd.isnull(row['Amiodarone (Cordarone)']) else row['Amiodarone (Cordarone)'],
        'Carbamazepine (Tegretol)': 0 if pd.isnull(row['Carbamazepine (Tegretol)']) else row['Carbamazepine (Tegretol)'],
        'Phenytoin (Dilantin)': 0 if pd.isnull(row['Phenytoin (Dilantin)']) else row['Phenytoin (Dilantin)'],
        'Rifampin or Rifampicin': 0 if pd.isnull(row['Rifampin or Rifampicin']) else row['Rifampin or Rifampicin'],
        'Sulfonamide Antibiotics': 0 if pd.isnull(row['Sulfonamide Antibiotics']) else row['Sulfonamide Antibiotics'],
        'Macrolide Antibiotics': 0 if pd.isnull(row['Macrolide Antibiotics']) else row['Macrolide Antibiotics'],
        'Anti-fungal Azoles': 0 if pd.isnull(row['Anti-fungal Azoles']) else row['Anti-fungal Azoles'],
        'Herbal Medications, Vitamins, Supplements': 0 if pd.isnull(row['Herbal Medications, Vitamins, Supplements']) else row['Herbal Medications, Vitamins, Supplements'],
        'Current Smoker': 0 if pd.isnull(row['Current Smoker']) else row['Current Smoker'],
    
        'Race Asian': 0,
        'Race Black or African American': 0,
        'Race Unknown': 0,
        'Race Caucasian or White': 0,

        'CYP2C9 *1': 0,
        'CYP2C9 *2': 0,
        'CYP2C9 *3': 0,
        'CYP2C9 *4': 0,
        'CYP2C9 *5': 0,
        'CYP2C9 *6': 0,
        'CYP2C9 *7': 0,
        'CYP2C9 *8': 0,
        'CYP2C9 *9': 0,
        'CYP2C9 *10': 0,
        'CYP2C9 *11': 0,
        'CYP2C9 *12': 0,
        'CYP2C9 *13': 0,
        'CYP2C9 *14': 0,
    
        'VKORC1 - -1639G>A': 0,
        'VKORC1 - 497T>G': 0,
        'VKORC1 - 1173C>T': 0,
        'VKORC1 - 1542G>C': 0,
        'VKORC1 - 3730G>A': 0,
        'VKORC1 - 2255C>T': 0,
        'VKORC1 - -4451C>A': 0,

        'Target INR': 0,
        'dose': row['Therapeutic Dose of Warfarin'],
        'type': 0
    }
    try:
        sample['Age in decades'] = int(str(row['Age']).split('-')[0].replace('+', '')) / 10
    except:
        continue

    if pd.isnull(row['Indication for Warfarin Treatment']):
        sample['Other']=1
    else:
        sample['DVT'] = str(row['Indication for Warfarin Treatment']).count('1')
        sample['PE'] = str(row['Indication for Warfarin Treatment']).count('2')
        sample['Afib/flutter'] = str(row['Indication for Warfarin Treatment']).count('3')
        sample['Heart Valve'] = str(row['Indication for Warfarin Treatment']).count('4')
        sample['Cardiomyopathy/LV Dilation'] = str(row['Indication for Warfarin Treatment']).count('5')
        sample['Stroke'] = str(row['Indication for Warfarin Treatment']).count('6')
        sample['Post-Orthopedic'] = str(row['Indication for Warfarin Treatment']).count('7')
        sample['Other'] = str(row['Indication for Warfarin Treatment']).count('8')

    match row['Race (OMB)']:
        case 'White':
            sample['Race Caucasian or White'] = 1
        case 'Asian':
            sample['Race Asian'] = 1
        case 'Black or African American':
            sample['Race Black or African American'] = 1
        case 'Unknown':
            sample['Race Unknown'] = 1

    if pd.isnull(row['VKORC1 -1639 consensus']):
        pass
    else:
        sample['VKORC1 - -1639G>A'] = str(row['VKORC1 -1639 consensus']).count('A')
        
    if pd.isnull(row['VKORC1 497 consensus']):
        pass
    else:
        sample['VKORC1 - 497T>G'] = str(row['VKORC1 497 consensus']).count('G')
        
    if pd.isnull(row['VKORC1 1173 consensus']):
        pass
    else:
        sample['VKORC1 - 1173C>T'] = str(row['VKORC1 1173 consensus']).count('T')
        
    if pd.isnull(row['VKORC1 1542 consensus']):
        pass
    else:
        sample['VKORC1 - 1542G>C'] = str(row['VKORC1 1542 consensus']).count('C')
        
    if pd.isnull(row['VKORC1 3730 consensus']):
        pass
    else:
        sample['VKORC1 - 3730G>A'] = str(row['VKORC1 3730 consensus']).count('A')
        
    if pd.isnull(row['VKORC1 2255 consensus']):
        pass
    else:
        sample['VKORC1 - 2255C>T'] = str(row['VKORC1 2255 consensus']).count('T')
        
    if pd.isnull(row['VKORC1 -4451 consensus']):
        pass
    else:
        sample['VKORC1 - -4451C>A'] = str(row['VKORC1 -4451 consensus']).count('A')

    sample['CYP2C9 *1'] = str(row['CYP2C9 consensus']).count('*1')
    sample['CYP2C9 *2'] = str(row['CYP2C9 consensus']).count('*2')
    sample['CYP2C9 *3'] = str(row['CYP2C9 consensus']).count('*3')
    sample['CYP2C9 *4'] = str(row['CYP2C9 consensus']).count('*4')
    sample['CYP2C9 *5'] = str(row['CYP2C9 consensus']).count('*5')
    sample['CYP2C9 *6'] = str(row['CYP2C9 consensus']).count('*6')
    sample['CYP2C9 *7'] = str(row['CYP2C9 consensus']).count('*7')
    sample['CYP2C9 *8'] = str(row['CYP2C9 consensus']).count('*8')
    sample['CYP2C9 *9'] = str(row['CYP2C9 consensus']).count('*9')
    sample['CYP2C9 *10'] = str(row['CYP2C9 consensus']).count('*10')
    sample['CYP2C9 *11'] = str(row['CYP2C9 consensus']).count('*11')
    sample['CYP2C9 *12'] = str(row['CYP2C9 consensus']).count('*12')
    sample['CYP2C9 *13'] = str(row['CYP2C9 consensus']).count('*13')
    sample['CYP2C9 *14'] = str(row['CYP2C9 consensus']).count('*14')

    if not pd.isnull(row['Target INR']):
        sample['Target INR'] = row['Target INR']
    else:
        if not pd.isnull(row['Estimated Target INR Range Based on Indication']):
            sample['Target INR'] = float(str(row['Estimated Target INR Range Based on Indication']).split('-')[1])
        else:
            continue
    
    if sample['dose'] < 7:
        sample['type'] = 0
    elif 7 <= sample['dose'] < 14:
        sample['type'] = 1
    elif 14 <= sample['dose'] < 21:
        sample['type'] = 2
    elif 21 <= sample['dose'] < 28:
        sample['type'] = 3
    elif 28 <= sample['dose'] < 35:
        sample['type'] = 4
    elif 35 <= sample['dose'] < 42:
        sample['type'] = 5
    elif 42 <= sample['dose'] < 52.5:
        sample['type'] = 6
    elif 52.5 <= sample['dose'] < 56:
        sample['type'] = 7
    elif 56 <= sample['dose'] < 70:
        sample['type'] = 8
    elif 70 <= sample['dose'] < 84:
        sample['type'] = 9
    elif 84 <= sample['dose'] < 105:
        sample['type'] = 10
    else:
        sample['type'] = 11
    warfarin_data.append(sample)

data = data._append(warfarin_data, ignore_index=True)

# %%
data.shape
# Out:
# (3663, 62)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3663 entries, 0 to 3662
# Data columns (total 62 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Gender                                                          3663 non-null   object
#  1   Age in decades                                                  3663 non-null   float64
#  2   Height (cm)                                                     3663 non-null   float64
#  3   Weight (kg)                                                     3663 non-null   float64
#  4   Race Asian                                                      3663 non-null   object
#  5   Race Black or African American                                  3663 non-null   object
#  6   Race Caucasian or White                                         3663 non-null   object
#  7   Race Unknown                                                    3663 non-null   object
#  8   DVT                                                             3663 non-null   object
#  9   PE                                                              3663 non-null   object
#  10  Afib/flutter                                                    3663 non-null   object
#  11  Heart Valve                                                     3663 non-null   object
#  12  Cardiomyopathy/LV Dilation                                      3663 non-null   object
#  13  Stroke                                                          3663 non-null   object
#  14  Post-Orthopedic                                                 3663 non-null   object
#  15  Other                                                           3663 non-null   object
#  16  Diabetes                                                        3663 non-null   float64
#  17  Congestive Heart Failure and/or Cardiomyopathy                  3663 non-null   float64
#  18  Valve Replacement                                               3663 non-null   float64
#  19  Aspirin                                                         3663 non-null   float64
#  20  Acetaminophen or Paracetamol (Tylenol)                          3663 non-null   float64
#  21  Was Dose of Acetaminophen or Paracetamol (Tylenol) >1300mg/day  3663 non-null   float64
#  22  Simvastatin (Zocor)                                             3663 non-null   float64
#  23  Atorvastatin (Lipitor)                                          3663 non-null   float64
#  24  Fluvastatin (Lescol)                                            3663 non-null   float64
#  25  Lovastatin (Mevacor)                                            3663 non-null   float64
#  26  Pravastatin (Pravachol)                                         3663 non-null   float64
#  27  Rosuvastatin (Crestor)                                          3663 non-null   float64
#  28  Cerivastatin (Baycol)                                           3663 non-null   float64
#  29  Amiodarone (Cordarone)                                          3663 non-null   float64
#  30  Carbamazepine (Tegretol)                                        3663 non-null   float64
#  31  Phenytoin (Dilantin)                                            3663 non-null   float64
#  32  Rifampin or Rifampicin                                          3663 non-null   float64
#  33  Sulfonamide Antibiotics                                         3663 non-null   float64
#  34  Macrolide Antibiotics                                           3663 non-null   float64
#  35  Anti-fungal Azoles                                              3663 non-null   float64
#  36  Herbal Medications, Vitamins, Supplements                       3663 non-null   float64
#  37  Current Smoker                                                  3663 non-null   float64
#  38  CYP2C9 *1                                                       3663 non-null   object
#  39  CYP2C9 *2                                                       3663 non-null   object
#  40  CYP2C9 *3                                                       3663 non-null   object
#  41  CYP2C9 *4                                                       3663 non-null   object
#  42  CYP2C9 *5                                                       3663 non-null   object
#  43  CYP2C9 *6                                                       3663 non-null   object
#  44  CYP2C9 *7                                                       3663 non-null   object
#  45  CYP2C9 *8                                                       3663 non-null   object
#  46  CYP2C9 *9                                                       3663 non-null   object
#  47  CYP2C9 *10                                                      3663 non-null   object
#  48  CYP2C9 *11                                                      3663 non-null   object
#  49  CYP2C9 *12                                                      3663 non-null   object
#  50  CYP2C9 *13                                                      3663 non-null   object
#  51  CYP2C9 *14                                                      3663 non-null   object
#  52  VKORC1 - -1639G>A                                               3663 non-null   object
#  53  VKORC1 - 497T>G                                                 3663 non-null   object
#  54  VKORC1 - 1173C>T                                                3663 non-null   object
#  55  VKORC1 - 1542G>C                                                3663 non-null   object
#  56  VKORC1 - 3730G>A                                                3663 non-null   object
#  57  VKORC1 - 2255C>T                                                3663 non-null   object
#  58  VKORC1 - -4451C>A                                               3663 non-null   object
#  59  Target INR                                                      3663 non-null   float64
#  60  dose                                                            3663 non-null   float64
#  61  type                                                            3663 non-null   object
# dtypes: float64(27), object(35)
# memory usage: 1.7+ MB

# %% [markdown]
# ### split

# %%
data_size = len(data)
ratio = 0.7
pointer = int(ratio * data_size)
train_set = data.iloc[:pointer, :-2]
test_set = data.iloc[pointer:, :-2]
train_dose = data.iloc[:pointer, -1:].values
test_dose = data.iloc[pointer:, -1:].values

# %% [markdown]
# ### train

# %%
arms = np.arange(12)
accuracy = []
A_map = {}
b_map = {}
for arm in arms:
    A_map[arm] = np.identity(len(list(train_set)))
    b_map[arm] = np.zeros(len(list(train_set)))

for epoch in range(200):
    start_time = time.time()
    # train
    indices = np.random.permutation(list(range(len(train_set))))
    for i in indices:
        feature = np.array(train_set.iloc[i], dtype=float)
        # iterate through actions
        p = {}
        max_value = -np.inf
        max_arm = 0
        for arm in arms:
            theta = np.matmul(np.linalg.inv(A_map[arm]), b_map[arm])
            p = np.matmul(theta.T, feature) + \
                np.sqrt(np.matmul(np.matmul(feature.T, np.linalg.inv(A_map[arm])), feature))

            if p == max_value:
                if np.random.choice(a=[False, True]): max_arm = arm
            elif p > max_value:
                max_value = p
                max_arm = arm

        # observe reward and update A and b
        r = -abs(train_dose[i][0]-max_arm)
        A_map[max_arm] += np.outer(feature, feature)
        b_map[max_arm] += r * feature

    # test
    correct_count = 0
    count = 0
    higher = 0
    lower = 0
    for i in range(len(test_set)):
        count += 1
        feature = np.array(test_set.iloc[i], dtype=float)
        # iterate through actions
        p = {}
        max_value = -np.inf
        max_arm = 0
        for arm in arms:
            theta = np.matmul(np.linalg.inv(A_map[arm]), b_map[arm])
            p = np.matmul(theta.T, feature) + \
                np.sqrt(np.matmul(np.matmul(feature.T, np.linalg.inv(A_map[arm])), feature))
            if p == max_value:
                if np.random.choice(a=[False, True]): max_arm = arm
            elif p > max_value:
                max_value = p
                max_arm = arm

        if max_arm == test_dose[i]:
            correct_count += 1
        elif max_arm < test_dose[i]:
            lower += test_dose[i] - max_arm
        else:
            higher += max_arm - test_dose[i]

    end_time = time.time()
    accu = correct_count / count
    print("Epoch %d: Accuracy: %.5f%% (%d/%d), Higher: %d, Lower: %d, Time: %.5fs" % (
        epoch, accu * 100, correct_count, count, higher, lower, end_time - start_time))
    accuracy.append(accu)
# Out:
# Epoch 0: Accuracy: 21.20109% (233/1099), Higher: 946, Lower: 876, Time: 7.06138s
# Epoch 1: Accuracy: 20.10919% (221/1099), Higher: 925, Lower: 933, Time: 7.11481s
# Epoch 2: Accuracy: 20.29117% (223/1099), Higher: 918, Lower: 877, Time: 7.00373s
# Epoch 3: Accuracy: 20.83712% (229/1099), Higher: 881, Lower: 856, Time: 7.10317s
# Epoch 4: Accuracy: 20.29117% (223/1099), Higher: 897, Lower: 861, Time: 6.88031s
# Epoch 5: Accuracy: 21.01911% (231/1099), Higher: 917, Lower: 852, Time: 6.87660s
# Epoch 6: Accuracy: 21.20109% (233/1099), Higher: 909, Lower: 850, Time: 6.84979s
# Epoch 7: Accuracy: 21.56506% (237/1099), Higher: 908, Lower: 835, Time: 6.84212s
# Epoch 8: Accuracy: 21.92903% (241/1099), Higher: 918, Lower: 812, Time: 6.97275s
# Epoch 9: Accuracy: 21.74704% (239/1099), Higher: 921, Lower: 810, Time: 7.00091s
# Epoch 10: Accuracy: 21.74704% (239/1099), Higher: 974, Lower: 789, Time: 7.02265s
# Epoch 11: Accuracy: 21.38308% (235/1099), Higher: 979, Lower: 790, Time: 7.07802s
# Epoch 12: Accuracy: 20.92812% (230/1099), Higher: 985, Lower: 799, Time: 7.72016s
# Epoch 13: Accuracy: 21.01911% (231/1099), Higher: 981, Lower: 792, Time: 6.98692s
# Epoch 14: Accuracy: 20.65514% (227/1099), Higher: 984, Lower: 800, Time: 8.11185s
# Epoch 15: Accuracy: 21.11010% (232/1099), Higher: 985, Lower: 790, Time: 7.09363s
# Epoch 16: Accuracy: 20.65514% (227/1099), Higher: 979, Lower: 794, Time: 6.99535s
# Epoch 17: Accuracy: 20.65514% (227/1099), Higher: 989, Lower: 797, Time: 6.89287s
# Epoch 18: Accuracy: 20.65514% (227/1099), Higher: 979, Lower: 805, Time: 6.90153s
# Epoch 19: Accuracy: 20.74613% (228/1099), Higher: 975, Lower: 800, Time: 7.07217s
# Epoch 20: Accuracy: 20.92812% (230/1099), Higher: 975, Lower: 798, Time: 7.06784s
# Epoch 21: Accuracy: 20.92812% (230/1099), Higher: 981, Lower: 796, Time: 7.20850s
# Epoch 22: Accuracy: 20.92812% (230/1099), Higher: 977, Lower: 804, Time: 7.06139s
# Epoch 23: Accuracy: 20.83712% (229/1099), Higher: 977, Lower: 807, Time: 6.96684s
# Epoch 24: Accuracy: 20.83712% (229/1099), Higher: 969, Lower: 812, Time: 7.24744s
# Epoch 25: Accuracy: 21.01911% (231/1099), Higher: 967, Lower: 815, Time: 6.97702s
# Epoch 26: Accuracy: 20.92812% (230/1099), Higher: 962, Lower: 818, Time: 6.93445s
# Epoch 27: Accuracy: 21.11010% (232/1099), Higher: 956, Lower: 823, Time: 7.10448s
# Epoch 28: Accuracy: 21.20109% (233/1099), Higher: 954, Lower: 820, Time: 6.94838s
# Epoch 29: Accuracy: 21.29208% (234/1099), Higher: 949, Lower: 822, Time: 6.93353s
# Epoch 30: Accuracy: 21.11010% (232/1099), Higher: 951, Lower: 825, Time: 7.04725s
# Epoch 31: Accuracy: 20.92812% (230/1099), Higher: 950, Lower: 827, Time: 6.90936s
# Epoch 32: Accuracy: 21.01911% (231/1099), Higher: 951, Lower: 829, Time: 6.96331s
# Epoch 33: Accuracy: 21.11010% (232/1099), Higher: 948, Lower: 830, Time: 6.93980s
# Epoch 34: Accuracy: 20.92812% (230/1099), Higher: 948, Lower: 833, Time: 7.18198s
# Epoch 35: Accuracy: 20.83712% (229/1099), Higher: 950, Lower: 830, Time: 7.36528s
# Epoch 36: Accuracy: 21.20109% (233/1099), Higher: 944, Lower: 830, Time: 7.19193s
# Epoch 37: Accuracy: 21.01911% (231/1099), Higher: 949, Lower: 830, Time: 7.00247s
# Epoch 38: Accuracy: 21.01911% (231/1099), Higher: 949, Lower: 835, Time: 7.10411s
# Epoch 39: Accuracy: 20.92812% (230/1099), Higher: 949, Lower: 833, Time: 7.03032s
# Epoch 40: Accuracy: 21.01911% (231/1099), Higher: 948, Lower: 839, Time: 7.08542s
# Epoch 41: Accuracy: 21.11010% (232/1099), Higher: 946, Lower: 829, Time: 7.02919s
# Epoch 42: Accuracy: 21.11010% (232/1099), Higher: 948, Lower: 832, Time: 6.92474s
# Epoch 43: Accuracy: 21.20109% (233/1099), Higher: 944, Lower: 834, Time: 6.86390s
# Epoch 44: Accuracy: 21.20109% (233/1099), Higher: 947, Lower: 834, Time: 6.85151s
# Epoch 45: Accuracy: 21.29208% (234/1099), Higher: 945, Lower: 834, Time: 6.87487s
# Epoch 46: Accuracy: 21.38308% (235/1099), Higher: 933, Lower: 835, Time: 6.98392s
# Epoch 47: Accuracy: 21.20109% (233/1099), Higher: 934, Lower: 842, Time: 7.10365s
# Epoch 48: Accuracy: 21.11010% (232/1099), Higher: 939, Lower: 841, Time: 6.99630s
# Epoch 49: Accuracy: 20.92812% (230/1099), Higher: 937, Lower: 839, Time: 7.31371s
# Epoch 50: Accuracy: 20.83712% (229/1099), Higher: 940, Lower: 847, Time: 7.01430s
# Epoch 51: Accuracy: 20.74613% (228/1099), Higher: 939, Lower: 846, Time: 7.05353s
# Epoch 52: Accuracy: 20.92812% (230/1099), Higher: 938, Lower: 841, Time: 7.02513s
# Epoch 53: Accuracy: 20.83712% (229/1099), Higher: 939, Lower: 845, Time: 6.97194s
# Epoch 54: Accuracy: 20.83712% (229/1099), Higher: 939, Lower: 848, Time: 7.01955s
# Epoch 55: Accuracy: 20.92812% (230/1099), Higher: 933, Lower: 849, Time: 6.96519s
# Epoch 56: Accuracy: 20.92812% (230/1099), Higher: 941, Lower: 841, Time: 6.98411s
# Epoch 57: Accuracy: 20.92812% (230/1099), Higher: 940, Lower: 846, Time: 7.00102s
# Epoch 58: Accuracy: 20.92812% (230/1099), Higher: 935, Lower: 841, Time: 7.15285s
# Epoch 59: Accuracy: 20.92812% (230/1099), Higher: 937, Lower: 843, Time: 7.15326s
# Epoch 60: Accuracy: 21.01911% (231/1099), Higher: 931, Lower: 843, Time: 7.11314s
# Epoch 61: Accuracy: 20.92812% (230/1099), Higher: 933, Lower: 843, Time: 7.13754s
# Epoch 62: Accuracy: 20.92812% (230/1099), Higher: 935, Lower: 840, Time: 6.94526s
# Epoch 63: Accuracy: 21.20109% (233/1099), Higher: 931, Lower: 837, Time: 6.95854s
# Epoch 64: Accuracy: 21.01911% (231/1099), Higher: 933, Lower: 840, Time: 7.07223s
# Epoch 65: Accuracy: 21.11010% (232/1099), Higher: 936, Lower: 837, Time: 7.21695s
# Epoch 66: Accuracy: 21.20109% (233/1099), Higher: 934, Lower: 837, Time: 7.01750s
# Epoch 67: Accuracy: 21.29208% (234/1099), Higher: 933, Lower: 839, Time: 6.91466s
# Epoch 68: Accuracy: 21.11010% (232/1099), Higher: 936, Lower: 836, Time: 6.94983s
# Epoch 69: Accuracy: 21.11010% (232/1099), Higher: 936, Lower: 836, Time: 6.96446s
# Epoch 70: Accuracy: 21.20109% (233/1099), Higher: 936, Lower: 836, Time: 7.15060s
# Epoch 71: Accuracy: 21.11010% (232/1099), Higher: 935, Lower: 841, Time: 7.08162s
# Epoch 72: Accuracy: 21.11010% (232/1099), Higher: 936, Lower: 841, Time: 6.89287s
# Epoch 73: Accuracy: 21.01911% (231/1099), Higher: 934, Lower: 842, Time: 6.86550s
# Epoch 74: Accuracy: 21.11010% (232/1099), Higher: 937, Lower: 837, Time: 6.84387s
# Epoch 75: Accuracy: 21.11010% (232/1099), Higher: 934, Lower: 838, Time: 7.00416s
# Epoch 76: Accuracy: 21.11010% (232/1099), Higher: 934, Lower: 840, Time: 6.97443s
# Epoch 77: Accuracy: 21.11010% (232/1099), Higher: 931, Lower: 840, Time: 6.93642s
# Epoch 78: Accuracy: 21.01911% (231/1099), Higher: 936, Lower: 836, Time: 6.93017s
# Epoch 79: Accuracy: 21.01911% (231/1099), Higher: 932, Lower: 844, Time: 7.01553s
# Epoch 80: Accuracy: 20.92812% (230/1099), Higher: 933, Lower: 843, Time: 6.90515s
# Epoch 81: Accuracy: 21.11010% (232/1099), Higher: 935, Lower: 835, Time: 6.86042s
# Epoch 82: Accuracy: 21.01911% (231/1099), Higher: 934, Lower: 839, Time: 7.26294s
# Epoch 83: Accuracy: 20.92812% (230/1099), Higher: 936, Lower: 840, Time: 6.87619s
# Epoch 84: Accuracy: 20.92812% (230/1099), Higher: 934, Lower: 841, Time: 6.86567s
# Epoch 85: Accuracy: 20.83712% (229/1099), Higher: 936, Lower: 842, Time: 7.09027s
# Epoch 86: Accuracy: 21.01911% (231/1099), Higher: 937, Lower: 840, Time: 7.07437s
# Epoch 87: Accuracy: 20.92812% (230/1099), Higher: 935, Lower: 846, Time: 6.99443s
# Epoch 88: Accuracy: 20.92812% (230/1099), Higher: 935, Lower: 845, Time: 6.95579s
# Epoch 89: Accuracy: 20.83712% (229/1099), Higher: 939, Lower: 839, Time: 7.04439s
# Epoch 90: Accuracy: 20.74613% (228/1099), Higher: 939, Lower: 843, Time: 7.00262s
# Epoch 91: Accuracy: 20.56415% (226/1099), Higher: 945, Lower: 843, Time: 7.01214s
# Epoch 92: Accuracy: 20.83712% (229/1099), Higher: 932, Lower: 850, Time: 7.01318s
# Epoch 93: Accuracy: 20.65514% (227/1099), Higher: 937, Lower: 850, Time: 6.95790s
# Epoch 94: Accuracy: 20.65514% (227/1099), Higher: 942, Lower: 844, Time: 7.05280s
# Epoch 95: Accuracy: 20.56415% (226/1099), Higher: 944, Lower: 847, Time: 7.14861s
# Epoch 96: Accuracy: 20.65514% (227/1099), Higher: 942, Lower: 847, Time: 7.00274s
# Epoch 97: Accuracy: 20.56415% (226/1099), Higher: 942, Lower: 850, Time: 7.22648s
# Epoch 98: Accuracy: 20.56415% (226/1099), Higher: 942, Lower: 849, Time: 6.99478s
# Epoch 99: Accuracy: 20.65514% (227/1099), Higher: 941, Lower: 849, Time: 7.12292s
# Epoch 100: Accuracy: 20.74613% (228/1099), Higher: 942, Lower: 842, Time: 7.05133s
# Epoch 101: Accuracy: 20.74613% (228/1099), Higher: 945, Lower: 845, Time: 7.07479s
# Epoch 102: Accuracy: 20.74613% (228/1099), Higher: 945, Lower: 842, Time: 6.93991s
# Epoch 103: Accuracy: 20.56415% (226/1099), Higher: 945, Lower: 848, Time: 7.02901s
# Epoch 104: Accuracy: 20.65514% (227/1099), Higher: 946, Lower: 843, Time: 7.22299s
# Epoch 105: Accuracy: 20.56415% (226/1099), Higher: 946, Lower: 846, Time: 6.95207s
# Epoch 106: Accuracy: 20.83712% (229/1099), Higher: 943, Lower: 840, Time: 7.01629s
# Epoch 107: Accuracy: 20.74613% (228/1099), Higher: 944, Lower: 844, Time: 6.95007s
# Epoch 108: Accuracy: 20.74613% (228/1099), Higher: 946, Lower: 843, Time: 6.96564s
# Epoch 109: Accuracy: 20.83712% (229/1099), Higher: 944, Lower: 845, Time: 7.03428s
# Epoch 110: Accuracy: 20.65514% (227/1099), Higher: 945, Lower: 847, Time: 6.88550s
# Epoch 111: Accuracy: 20.74613% (228/1099), Higher: 947, Lower: 846, Time: 6.88452s
# Epoch 112: Accuracy: 20.83712% (229/1099), Higher: 941, Lower: 844, Time: 6.88106s
# Epoch 113: Accuracy: 20.74613% (228/1099), Higher: 943, Lower: 845, Time: 6.88737s
# Epoch 114: Accuracy: 20.74613% (228/1099), Higher: 945, Lower: 845, Time: 6.99269s
# Epoch 115: Accuracy: 20.74613% (228/1099), Higher: 943, Lower: 847, Time: 6.94105s
# Epoch 116: Accuracy: 20.83712% (229/1099), Higher: 940, Lower: 847, Time: 6.96375s
# Epoch 117: Accuracy: 20.83712% (229/1099), Higher: 939, Lower: 849, Time: 7.04913s
# Epoch 118: Accuracy: 20.74613% (228/1099), Higher: 943, Lower: 849, Time: 6.90543s
# Epoch 119: Accuracy: 20.74613% (228/1099), Higher: 946, Lower: 847, Time: 7.00912s
# Epoch 120: Accuracy: 20.56415% (226/1099), Higher: 946, Lower: 853, Time: 6.98395s
# Epoch 121: Accuracy: 20.56415% (226/1099), Higher: 946, Lower: 853, Time: 6.92311s
# Epoch 122: Accuracy: 20.74613% (228/1099), Higher: 943, Lower: 849, Time: 6.98667s
# Epoch 123: Accuracy: 20.92812% (230/1099), Higher: 943, Lower: 847, Time: 7.01866s
# Epoch 124: Accuracy: 20.47316% (225/1099), Higher: 948, Lower: 857, Time: 7.03493s
# Epoch 125: Accuracy: 20.65514% (227/1099), Higher: 945, Lower: 851, Time: 7.01969s
# Epoch 126: Accuracy: 20.65514% (227/1099), Higher: 941, Lower: 853, Time: 7.01980s
# Epoch 127: Accuracy: 20.56415% (226/1099), Higher: 948, Lower: 853, Time: 7.07121s
# Epoch 128: Accuracy: 20.56415% (226/1099), Higher: 945, Lower: 857, Time: 6.98271s
# Epoch 129: Accuracy: 20.56415% (226/1099), Higher: 946, Lower: 857, Time: 7.04431s
# Epoch 130: Accuracy: 20.56415% (226/1099), Higher: 946, Lower: 859, Time: 7.00967s
# Epoch 131: Accuracy: 20.47316% (225/1099), Higher: 948, Lower: 860, Time: 6.95834s
# Epoch 132: Accuracy: 20.47316% (225/1099), Higher: 949, Lower: 857, Time: 6.90638s
# Epoch 133: Accuracy: 20.47316% (225/1099), Higher: 946, Lower: 858, Time: 6.91985s
# Epoch 134: Accuracy: 20.56415% (226/1099), Higher: 945, Lower: 860, Time: 7.14492s
# Epoch 135: Accuracy: 20.56415% (226/1099), Higher: 945, Lower: 859, Time: 6.88423s
# Epoch 136: Accuracy: 20.56415% (226/1099), Higher: 945, Lower: 857, Time: 6.89619s
# Epoch 137: Accuracy: 20.56415% (226/1099), Higher: 942, Lower: 858, Time: 7.14387s
# Epoch 138: Accuracy: 20.56415% (226/1099), Higher: 942, Lower: 858, Time: 7.08013s
# Epoch 139: Accuracy: 20.65514% (227/1099), Higher: 945, Lower: 858, Time: 6.87818s
# Epoch 140: Accuracy: 20.65514% (227/1099), Higher: 946, Lower: 855, Time: 6.87874s
# Epoch 141: Accuracy: 20.65514% (227/1099), Higher: 943, Lower: 855, Time: 6.94142s
# Epoch 142: Accuracy: 20.56415% (226/1099), Higher: 947, Lower: 855, Time: 7.10365s
# Epoch 143: Accuracy: 20.65514% (227/1099), Higher: 944, Lower: 855, Time: 6.91971s
# Epoch 144: Accuracy: 20.47316% (225/1099), Higher: 942, Lower: 861, Time: 6.95038s
# Epoch 145: Accuracy: 20.47316% (225/1099), Higher: 939, Lower: 864, Time: 7.03890s
# Epoch 146: Accuracy: 20.47316% (225/1099), Higher: 939, Lower: 864, Time: 6.89160s
# Epoch 147: Accuracy: 20.56415% (226/1099), Higher: 936, Lower: 862, Time: 6.93477s
# Epoch 148: Accuracy: 20.56415% (226/1099), Higher: 935, Lower: 864, Time: 6.97207s
# Epoch 149: Accuracy: 20.47316% (225/1099), Higher: 938, Lower: 872, Time: 7.18220s
# Epoch 150: Accuracy: 20.47316% (225/1099), Higher: 939, Lower: 869, Time: 6.88519s
# Epoch 151: Accuracy: 20.38217% (224/1099), Higher: 941, Lower: 871, Time: 6.91934s
# Epoch 152: Accuracy: 20.38217% (224/1099), Higher: 939, Lower: 874, Time: 6.99892s
# Epoch 153: Accuracy: 20.38217% (224/1099), Higher: 939, Lower: 871, Time: 7.03724s
# Epoch 154: Accuracy: 20.29117% (223/1099), Higher: 937, Lower: 876, Time: 7.06050s
# Epoch 155: Accuracy: 20.29117% (223/1099), Higher: 938, Lower: 875, Time: 7.20399s
# Epoch 156: Accuracy: 20.38217% (224/1099), Higher: 939, Lower: 875, Time: 6.99432s
# Epoch 157: Accuracy: 20.29117% (223/1099), Higher: 941, Lower: 877, Time: 7.01464s
# Epoch 158: Accuracy: 20.29117% (223/1099), Higher: 942, Lower: 874, Time: 6.94064s
# Epoch 159: Accuracy: 20.29117% (223/1099), Higher: 940, Lower: 873, Time: 7.01638s
# Epoch 160: Accuracy: 20.29117% (223/1099), Higher: 941, Lower: 873, Time: 7.05785s
# Epoch 161: Accuracy: 20.29117% (223/1099), Higher: 941, Lower: 875, Time: 7.05451s
# Epoch 162: Accuracy: 20.29117% (223/1099), Higher: 941, Lower: 872, Time: 6.99371s
# Epoch 163: Accuracy: 20.29117% (223/1099), Higher: 943, Lower: 871, Time: 6.96716s
# Epoch 164: Accuracy: 20.20018% (222/1099), Higher: 938, Lower: 874, Time: 6.99128s
# Epoch 165: Accuracy: 20.20018% (222/1099), Higher: 939, Lower: 876, Time: 6.99264s
# Epoch 166: Accuracy: 20.20018% (222/1099), Higher: 940, Lower: 876, Time: 7.04760s
# Epoch 167: Accuracy: 20.20018% (222/1099), Higher: 940, Lower: 876, Time: 7.06894s
# Epoch 168: Accuracy: 20.20018% (222/1099), Higher: 940, Lower: 876, Time: 7.25647s
# Epoch 169: Accuracy: 20.29117% (223/1099), Higher: 941, Lower: 874, Time: 6.98216s
# Epoch 170: Accuracy: 20.29117% (223/1099), Higher: 940, Lower: 874, Time: 7.16955s
# Epoch 171: Accuracy: 20.38217% (224/1099), Higher: 942, Lower: 870, Time: 7.05882s
# Epoch 172: Accuracy: 20.47316% (225/1099), Higher: 938, Lower: 872, Time: 7.16142s
# Epoch 173: Accuracy: 20.38217% (224/1099), Higher: 941, Lower: 870, Time: 7.02677s
# Epoch 174: Accuracy: 20.47316% (225/1099), Higher: 937, Lower: 871, Time: 7.14663s
# Epoch 175: Accuracy: 20.38217% (224/1099), Higher: 938, Lower: 871, Time: 7.05327s
# Epoch 176: Accuracy: 20.29117% (223/1099), Higher: 940, Lower: 870, Time: 6.99792s
# Epoch 177: Accuracy: 20.20018% (222/1099), Higher: 944, Lower: 870, Time: 6.93698s
# Epoch 178: Accuracy: 20.29117% (223/1099), Higher: 943, Lower: 870, Time: 7.15164s
# Epoch 179: Accuracy: 20.38217% (224/1099), Higher: 940, Lower: 871, Time: 6.91189s
# Epoch 180: Accuracy: 20.29117% (223/1099), Higher: 942, Lower: 868, Time: 6.88821s
# Epoch 181: Accuracy: 20.29117% (223/1099), Higher: 943, Lower: 868, Time: 6.85618s
# Epoch 182: Accuracy: 20.29117% (223/1099), Higher: 943, Lower: 868, Time: 6.88884s
# Epoch 183: Accuracy: 20.29117% (223/1099), Higher: 942, Lower: 868, Time: 7.05414s
# Epoch 184: Accuracy: 20.29117% (223/1099), Higher: 943, Lower: 868, Time: 6.92047s
# Epoch 185: Accuracy: 20.29117% (223/1099), Higher: 943, Lower: 868, Time: 6.88765s
# Epoch 186: Accuracy: 20.29117% (223/1099), Higher: 942, Lower: 871, Time: 7.00013s
# Epoch 187: Accuracy: 20.29117% (223/1099), Higher: 945, Lower: 869, Time: 6.91434s
# Epoch 188: Accuracy: 20.29117% (223/1099), Higher: 941, Lower: 871, Time: 7.20953s
# Epoch 189: Accuracy: 20.29117% (223/1099), Higher: 942, Lower: 868, Time: 7.06737s
# Epoch 190: Accuracy: 20.29117% (223/1099), Higher: 942, Lower: 868, Time: 6.95646s
# Epoch 191: Accuracy: 20.29117% (223/1099), Higher: 944, Lower: 869, Time: 6.88983s
# Epoch 192: Accuracy: 20.29117% (223/1099), Higher: 941, Lower: 871, Time: 6.88464s
# Epoch 193: Accuracy: 20.29117% (223/1099), Higher: 942, Lower: 868, Time: 6.89707s
# Epoch 194: Accuracy: 20.29117% (223/1099), Higher: 941, Lower: 871, Time: 6.91375s
# Epoch 195: Accuracy: 20.29117% (223/1099), Higher: 942, Lower: 868, Time: 7.00911s
# Epoch 196: Accuracy: 20.29117% (223/1099), Higher: 945, Lower: 866, Time: 7.24315s
# Epoch 197: Accuracy: 20.29117% (223/1099), Higher: 945, Lower: 866, Time: 7.11747s
# Epoch 198: Accuracy: 20.29117% (223/1099), Higher: 945, Lower: 866, Time: 7.11082s
# Epoch 199: Accuracy: 20.29117% (223/1099), Higher: 945, Lower: 866, Time: 7.05766s

# %%
plt.plot(accuracy)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# ### validate

# %%
val_set = data.iloc[:, :-2]
val_dose = data.iloc[:, -1:].values

# %%
arms = np.arange(12)
correct_count = 0
count = 0
heatmap = np.zeros((12, 12))

for i in range(len(data)):
    count += 1
    feature = np.array(val_set.iloc[i], dtype=float)
    # iterate through actions
    p = {}
    max_value = -np.inf
    max_arm = 0
    for arm in arms:
        theta = np.matmul(np.linalg.inv(A_map[arm]), b_map[arm])
        p = np.matmul(theta.T, feature) + \
            np.sqrt(np.matmul(np.matmul(feature.T, np.linalg.inv(A_map[arm])), feature))
        if p == max_value:
            if np.random.choice(a=[False, True]): max_arm = arm
        elif p > max_value:
            max_value = p
            max_arm = arm

    if max_arm == val_dose[i][0]:
        correct_count += 1
    heatmap[max_arm][int(val_dose[i][0])] += 1

accu = correct_count / count
print("Validate: Accuracy: %.5f%% (%d/%d)" % (accu * 100, correct_count, count))
# Out:
# Validate: Accuracy: 27.87333% (1021/3663)

# %%
ax = sns.heatmap(heatmap, linewidth=0.5, annot=True, cmap='Blues', fmt='.20g')
plt.show()

# %% [markdown]
# ## Long range
# ### Filter

# %%
data1 = data.copy()
data1.loc[data1['dose'] < 21,'type'] = 0
data1.loc[(data1['dose'] >= 21) & (data1['dose'] < 49),'type'] = 1
data1.loc[data1['dose'] >= 49,'type'] = 2

# %% [markdown]
# ### Split

# %%
data_size1 = len(data1)
ratio1 = 0.7
pointer = int(ratio1 * data_size1)
train_set1 = data1.iloc[:pointer, :-2]
test_set1 = data1.iloc[pointer:, :-2]
train_dose1 = data1.iloc[:pointer, -1:].values
test_dose1 = data1.iloc[pointer:, -1:].values

# %% [markdown]
# ### Train

# %%
arms = np.arange(3)
accuracy1 = []
A_map1 = {}
b_map1 = {}
for arm in arms:
    A_map1[arm] = np.identity(len(list(train_set1)))
    b_map1[arm] = np.zeros(len(list(train_set1)))

for epoch in range(200):
    start_time = time.time()
    # train
    indices = np.random.permutation(list(range(len(train_set1))))
    for i in indices:
        feature = np.array(train_set1.iloc[i], dtype=float)
        # iterate through actions
        p = {}
        max_value = -np.inf
        max_arm = 0
        for arm in arms:
            theta = np.matmul(np.linalg.inv(A_map1[arm]), b_map1[arm])
            p = np.matmul(theta.T, feature) + \
                np.sqrt(np.matmul(np.matmul(feature.T, np.linalg.inv(A_map1[arm])), feature))

            if p == max_value:
                if np.random.choice(a=[False, True]): max_arm = arm
            elif p > max_value:
                max_value = p
                max_arm = arm

        # observe reward and update A and b
        r = -abs(train_dose1[i][0]-max_arm)
        A_map1[max_arm] += np.outer(feature, feature)
        b_map1[max_arm] += r * feature

    # test
    correct_count = 0
    count = 0
    higher = 0
    lower = 0
    for i in range(len(test_set1)):
        count += 1
        feature = np.array(test_set1.iloc[i], dtype=float)
        # iterate through actions
        p = {}
        max_value = -np.inf
        max_arm = 0
        for arm in arms:
            theta = np.matmul(np.linalg.inv(A_map1[arm]), b_map1[arm])
            p = np.matmul(theta.T, feature) + \
                np.sqrt(np.matmul(np.matmul(feature.T, np.linalg.inv(A_map1[arm])), feature))
            if p == max_value:
                if np.random.choice(a=[False, True]): max_arm = arm
            elif p > max_value:
                max_value = p
                max_arm = arm

        if max_arm == test_dose1[i]:
            correct_count += 1
        elif max_arm < test_dose1[i]:
            lower += test_dose1[i] - max_arm
        else:
            higher += max_arm - test_dose1[i]

    end_time = time.time()
    accu = correct_count / count
    print("Epoch %d: Accuracy: %.5f%% (%d/%d), Higher: %d, Lower: %d, Time: %.5fs" % (
        epoch, accu * 100, correct_count, count, higher, lower, end_time - start_time))
    accuracy1.append(accu)
# Out:
# Epoch 0: Accuracy: 64.24022% (706/1099), Higher: 195, Lower: 204, Time: 2.06102s
# Epoch 1: Accuracy: 64.14923% (705/1099), Higher: 197, Lower: 204, Time: 2.07884s
# Epoch 2: Accuracy: 64.96815% (714/1099), Higher: 194, Lower: 198, Time: 2.06906s
# Epoch 3: Accuracy: 65.42311% (719/1099), Higher: 193, Lower: 194, Time: 2.07129s
# Epoch 4: Accuracy: 65.24113% (717/1099), Higher: 194, Lower: 196, Time: 2.10533s
# Epoch 5: Accuracy: 65.24113% (717/1099), Higher: 196, Lower: 194, Time: 2.17562s
# Epoch 6: Accuracy: 64.96815% (714/1099), Higher: 198, Lower: 194, Time: 2.17075s
# Epoch 7: Accuracy: 64.78617% (712/1099), Higher: 199, Lower: 195, Time: 2.11675s
# Epoch 8: Accuracy: 65.15014% (716/1099), Higher: 198, Lower: 192, Time: 2.07585s
# Epoch 9: Accuracy: 65.05914% (715/1099), Higher: 200, Lower: 191, Time: 2.05047s
# Epoch 10: Accuracy: 65.05914% (715/1099), Higher: 200, Lower: 191, Time: 2.05329s
# Epoch 11: Accuracy: 65.33212% (718/1099), Higher: 198, Lower: 190, Time: 2.04746s
# Epoch 12: Accuracy: 65.42311% (719/1099), Higher: 198, Lower: 189, Time: 2.05223s
# Epoch 13: Accuracy: 65.33212% (718/1099), Higher: 198, Lower: 190, Time: 2.05371s
# Epoch 14: Accuracy: 65.69609% (722/1099), Higher: 196, Lower: 188, Time: 2.06093s
# Epoch 15: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 188, Time: 2.13988s
# Epoch 16: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 188, Time: 2.07103s
# Epoch 17: Accuracy: 65.78708% (723/1099), Higher: 196, Lower: 188, Time: 2.12405s
# Epoch 18: Accuracy: 65.78708% (723/1099), Higher: 196, Lower: 188, Time: 2.07435s
# Epoch 19: Accuracy: 65.87807% (724/1099), Higher: 194, Lower: 188, Time: 2.06968s
# Epoch 20: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 189, Time: 2.11236s
# Epoch 21: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 189, Time: 2.08047s
# Epoch 22: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 189, Time: 2.08543s
# Epoch 23: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 189, Time: 2.15273s
# Epoch 24: Accuracy: 65.78708% (723/1099), Higher: 195, Lower: 188, Time: 2.11473s
# Epoch 25: Accuracy: 65.69609% (722/1099), Higher: 196, Lower: 188, Time: 2.11380s
# Epoch 26: Accuracy: 65.78708% (723/1099), Higher: 195, Lower: 188, Time: 2.11699s
# Epoch 27: Accuracy: 65.78708% (723/1099), Higher: 196, Lower: 187, Time: 2.14325s
# Epoch 28: Accuracy: 65.69609% (722/1099), Higher: 196, Lower: 188, Time: 2.10946s
# Epoch 29: Accuracy: 65.60510% (721/1099), Higher: 197, Lower: 188, Time: 2.08798s
# Epoch 30: Accuracy: 65.69609% (722/1099), Higher: 196, Lower: 188, Time: 2.09922s
# Epoch 31: Accuracy: 65.69609% (722/1099), Higher: 196, Lower: 188, Time: 2.09703s
# Epoch 32: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.09310s
# Epoch 33: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.10479s
# Epoch 34: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.09862s
# Epoch 35: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.10383s
# Epoch 36: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.10224s
# Epoch 37: Accuracy: 65.78708% (723/1099), Higher: 196, Lower: 187, Time: 2.09981s
# Epoch 38: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.07876s
# Epoch 39: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.10547s
# Epoch 40: Accuracy: 65.60510% (721/1099), Higher: 198, Lower: 187, Time: 2.10365s
# Epoch 41: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.08937s
# Epoch 42: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.07843s
# Epoch 43: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.08710s
# Epoch 44: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.08136s
# Epoch 45: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.11890s
# Epoch 46: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.08196s
# Epoch 47: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.08783s
# Epoch 48: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.15751s
# Epoch 49: Accuracy: 65.78708% (723/1099), Higher: 196, Lower: 187, Time: 2.09135s
# Epoch 50: Accuracy: 65.78708% (723/1099), Higher: 196, Lower: 187, Time: 2.08261s
# Epoch 51: Accuracy: 65.78708% (723/1099), Higher: 196, Lower: 187, Time: 2.09078s
# Epoch 52: Accuracy: 65.78708% (723/1099), Higher: 196, Lower: 187, Time: 2.19462s
# Epoch 53: Accuracy: 65.78708% (723/1099), Higher: 196, Lower: 187, Time: 2.24496s
# Epoch 54: Accuracy: 65.78708% (723/1099), Higher: 196, Lower: 187, Time: 2.17734s
# Epoch 55: Accuracy: 65.78708% (723/1099), Higher: 196, Lower: 187, Time: 2.14499s
# Epoch 56: Accuracy: 65.78708% (723/1099), Higher: 196, Lower: 187, Time: 2.11112s
# Epoch 57: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.09766s
# Epoch 58: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.08244s
# Epoch 59: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.08711s
# Epoch 60: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.09697s
# Epoch 61: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.10114s
# Epoch 62: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.08332s
# Epoch 63: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.08605s
# Epoch 64: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.08305s
# Epoch 65: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.08833s
# Epoch 66: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 187, Time: 2.07900s
# Epoch 67: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.10972s
# Epoch 68: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.21673s
# Epoch 69: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.08668s
# Epoch 70: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.16689s
# Epoch 71: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.09790s
# Epoch 72: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.08155s
# Epoch 73: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.13990s
# Epoch 74: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.21491s
# Epoch 75: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.19308s
# Epoch 76: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.08251s
# Epoch 77: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.08411s
# Epoch 78: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.08317s
# Epoch 79: Accuracy: 65.87807% (724/1099), Higher: 196, Lower: 186, Time: 2.11653s
# Epoch 80: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.10320s
# Epoch 81: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.09178s
# Epoch 82: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.09707s
# Epoch 83: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.09187s
# Epoch 84: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.08236s
# Epoch 85: Accuracy: 65.87807% (724/1099), Higher: 196, Lower: 186, Time: 2.08866s
# Epoch 86: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.07788s
# Epoch 87: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.08958s
# Epoch 88: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.08130s
# Epoch 89: Accuracy: 65.78708% (723/1099), Higher: 196, Lower: 186, Time: 2.08264s
# Epoch 90: Accuracy: 65.78708% (723/1099), Higher: 197, Lower: 186, Time: 2.08827s
# Epoch 91: Accuracy: 65.87807% (724/1099), Higher: 196, Lower: 186, Time: 2.08933s
# Epoch 92: Accuracy: 65.87807% (724/1099), Higher: 195, Lower: 186, Time: 2.08046s
# Epoch 93: Accuracy: 65.87807% (724/1099), Higher: 195, Lower: 186, Time: 2.08601s
# Epoch 94: Accuracy: 65.96906% (725/1099), Higher: 194, Lower: 186, Time: 2.08355s
# Epoch 95: Accuracy: 65.87807% (724/1099), Higher: 195, Lower: 186, Time: 2.15571s
# Epoch 96: Accuracy: 65.69609% (722/1099), Higher: 197, Lower: 186, Time: 2.08689s
# Epoch 97: Accuracy: 65.78708% (723/1099), Higher: 196, Lower: 186, Time: 2.09414s
# Epoch 98: Accuracy: 65.87807% (724/1099), Higher: 195, Lower: 186, Time: 2.08809s
# Epoch 99: Accuracy: 65.87807% (724/1099), Higher: 195, Lower: 186, Time: 2.13539s
# Epoch 100: Accuracy: 65.78708% (723/1099), Higher: 195, Lower: 187, Time: 2.13168s
# Epoch 101: Accuracy: 65.78708% (723/1099), Higher: 195, Lower: 187, Time: 2.09759s
# Epoch 102: Accuracy: 65.51410% (720/1099), Higher: 197, Lower: 188, Time: 2.07860s
# Epoch 103: Accuracy: 65.78708% (723/1099), Higher: 195, Lower: 187, Time: 2.09122s
# Epoch 104: Accuracy: 65.78708% (723/1099), Higher: 195, Lower: 187, Time: 2.08066s
# Epoch 105: Accuracy: 65.78708% (723/1099), Higher: 195, Lower: 187, Time: 2.13206s
# Epoch 106: Accuracy: 65.78708% (723/1099), Higher: 195, Lower: 187, Time: 2.20680s
# Epoch 107: Accuracy: 65.69609% (722/1099), Higher: 196, Lower: 187, Time: 2.19671s
# Epoch 108: Accuracy: 65.69609% (722/1099), Higher: 196, Lower: 187, Time: 2.09339s
# Epoch 109: Accuracy: 65.78708% (723/1099), Higher: 195, Lower: 187, Time: 2.08681s
# Epoch 110: Accuracy: 65.78708% (723/1099), Higher: 194, Lower: 188, Time: 2.08625s
# Epoch 111: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 188, Time: 2.21076s
# Epoch 112: Accuracy: 65.78708% (723/1099), Higher: 195, Lower: 187, Time: 2.10950s
# Epoch 113: Accuracy: 65.78708% (723/1099), Higher: 195, Lower: 187, Time: 2.08864s
# Epoch 114: Accuracy: 65.78708% (723/1099), Higher: 195, Lower: 187, Time: 2.07964s
# Epoch 115: Accuracy: 65.78708% (723/1099), Higher: 195, Lower: 187, Time: 2.08695s
# Epoch 116: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 188, Time: 2.17912s
# Epoch 117: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 188, Time: 2.18078s
# Epoch 118: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 188, Time: 2.13323s
# Epoch 119: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 188, Time: 2.15814s
# Epoch 120: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 188, Time: 2.18592s
# Epoch 121: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 188, Time: 2.20986s
# Epoch 122: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 188, Time: 2.11429s
# Epoch 123: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 188, Time: 2.06943s
# Epoch 124: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 188, Time: 2.06921s
# Epoch 125: Accuracy: 65.69609% (722/1099), Higher: 195, Lower: 188, Time: 2.06926s
# Epoch 126: Accuracy: 65.60510% (721/1099), Higher: 195, Lower: 189, Time: 2.06305s
# Epoch 127: Accuracy: 65.60510% (721/1099), Higher: 195, Lower: 189, Time: 2.06844s
# Epoch 128: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 190, Time: 2.13607s
# Epoch 129: Accuracy: 65.60510% (721/1099), Higher: 195, Lower: 189, Time: 2.07189s
# Epoch 130: Accuracy: 65.60510% (721/1099), Higher: 195, Lower: 189, Time: 2.06834s
# Epoch 131: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 190, Time: 2.07233s
# Epoch 132: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 190, Time: 2.06885s
# Epoch 133: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.08269s
# Epoch 134: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.17121s
# Epoch 135: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 190, Time: 2.21764s
# Epoch 136: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 190, Time: 2.16660s
# Epoch 137: Accuracy: 65.60510% (721/1099), Higher: 195, Lower: 188, Time: 2.10834s
# Epoch 138: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.12640s
# Epoch 139: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.23285s
# Epoch 140: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.17524s
# Epoch 141: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.15159s
# Epoch 142: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.11515s
# Epoch 143: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.12027s
# Epoch 144: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.12731s
# Epoch 145: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.10094s
# Epoch 146: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.17057s
# Epoch 147: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.16464s
# Epoch 148: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.09884s
# Epoch 149: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.09923s
# Epoch 150: Accuracy: 65.60510% (721/1099), Higher: 195, Lower: 188, Time: 2.11348s
# Epoch 151: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.15023s
# Epoch 152: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.10861s
# Epoch 153: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.09552s
# Epoch 154: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.09876s
# Epoch 155: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.09211s
# Epoch 156: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.08846s
# Epoch 157: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.07117s
# Epoch 158: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.07338s
# Epoch 159: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.07298s
# Epoch 160: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.07471s
# Epoch 161: Accuracy: 65.60510% (721/1099), Higher: 195, Lower: 188, Time: 2.07950s
# Epoch 162: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.07994s
# Epoch 163: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.06817s
# Epoch 164: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.07443s
# Epoch 165: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.08734s
# Epoch 166: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.08456s
# Epoch 167: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.08333s
# Epoch 168: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.10527s
# Epoch 169: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.09669s
# Epoch 170: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.08882s
# Epoch 171: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.08221s
# Epoch 172: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.13382s
# Epoch 173: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.13825s
# Epoch 174: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.11612s
# Epoch 175: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.09574s
# Epoch 176: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.08962s
# Epoch 177: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.09704s
# Epoch 178: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.20866s
# Epoch 179: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.21727s
# Epoch 180: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.24129s
# Epoch 181: Accuracy: 65.51410% (720/1099), Higher: 195, Lower: 189, Time: 2.26505s
# Epoch 182: Accuracy: 65.60510% (721/1099), Higher: 195, Lower: 188, Time: 2.37403s
# Epoch 183: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.12160s
# Epoch 184: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.15480s
# Epoch 185: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.12297s
# Epoch 186: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.11819s
# Epoch 187: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.11891s
# Epoch 188: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.12729s
# Epoch 189: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.11213s
# Epoch 190: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.21708s
# Epoch 191: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.11334s
# Epoch 192: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.15591s
# Epoch 193: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.09018s
# Epoch 194: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.07352s
# Epoch 195: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.08498s
# Epoch 196: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.07504s
# Epoch 197: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.08460s
# Epoch 198: Accuracy: 65.33212% (718/1099), Higher: 196, Lower: 190, Time: 2.08017s
# Epoch 199: Accuracy: 65.42311% (719/1099), Higher: 196, Lower: 189, Time: 2.07893s

# %%
plt.plot(accuracy1)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# ### Validate

# %%
val_set1 = data1.iloc[:, :-2]
val_dose1 = data1.iloc[:, -1:].values

# %%
arms = np.arange(3)
correct_count = 0
count = 0
heatmap1 = np.zeros((3, 3))

for i in range(len(data1)):
    count += 1
    feature = np.array(val_set1.iloc[i], dtype=float)
    # iterate through actions
    p = {}
    max_value = -np.inf
    max_arm = 0
    for arm in arms:
        theta = np.matmul(np.linalg.inv(A_map1[arm]), b_map1[arm])
        p = np.matmul(theta.T, feature) + \
            np.sqrt(np.matmul(np.matmul(feature.T, np.linalg.inv(A_map1[arm])), feature))
        if p == max_value:
            if np.random.choice(a=[False, True]): max_arm = arm
        elif p > max_value:
            max_value = p
            max_arm = arm

    if max_arm == val_dose1[i][0]:
        correct_count += 1
    heatmap1[max_arm][int(val_dose1[i][0])] += 1

accu = correct_count / count
print("Validate: Accuracy: %.5f%% (%d/%d)" % (accu * 100, correct_count, count))
# Out:
# Validate: Accuracy: 71.25307% (2610/3663)

# %%
ax = sns.heatmap(heatmap1, linewidth=0.5, annot=True, cmap='Blues', fmt='.20g')
plt.show()

# %% [markdown]
# # Train and test on real data with threshold
# ## Short range
# ### Filter

# %%
data2 = data.drop(data.columns[data.sum() < data_size*0.05], axis=1)
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3663 entries, 0 to 3662
# Data columns (total 36 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Gender                                          3663 non-null   object
#  1   Age in decades                                  3663 non-null   float64
#  2   Height (cm)                                     3663 non-null   float64
#  3   Weight (kg)                                     3663 non-null   float64
#  4   Race Asian                                      3663 non-null   object
#  5   Race Black or African American                  3663 non-null   object
#  6   Race Caucasian or White                         3663 non-null   object
#  7   Race Unknown                                    3663 non-null   object
#  8   DVT                                             3663 non-null   object
#  9   PE                                              3663 non-null   object
#  10  Afib/flutter                                    3663 non-null   object
#  11  Heart Valve                                     3663 non-null   object
#  12  Other                                           3663 non-null   object
#  13  Diabetes                                        3663 non-null   float64
#  14  Congestive Heart Failure and/or Cardiomyopathy  3663 non-null   float64
#  15  Valve Replacement                               3663 non-null   float64
#  16  Aspirin                                         3663 non-null   float64
#  17  Acetaminophen or Paracetamol (Tylenol)          3663 non-null   float64
#  18  Simvastatin (Zocor)                             3663 non-null   float64
#  19  Atorvastatin (Lipitor)                          3663 non-null   float64
#  20  Amiodarone (Cordarone)                          3663 non-null   float64
#  21  Herbal Medications, Vitamins, Supplements       3663 non-null   float64
#  22  Current Smoker                                  3663 non-null   float64
#  23  CYP2C9 *1                                       3663 non-null   object
#  24  CYP2C9 *2                                       3663 non-null   object
#  25  CYP2C9 *3                                       3663 non-null   object
#  26  VKORC1 - -1639G>A                               3663 non-null   object
#  27  VKORC1 - 497T>G                                 3663 non-null   object
#  28  VKORC1 - 1173C>T                                3663 non-null   object
#  29  VKORC1 - 1542G>C                                3663 non-null   object
#  30  VKORC1 - 3730G>A                                3663 non-null   object
#  31  VKORC1 - 2255C>T                                3663 non-null   object
#  32  VKORC1 - -4451C>A                               3663 non-null   object
#  33  Target INR                                      3663 non-null   float64
#  34  dose                                            3663 non-null   float64
#  35  type                                            3663 non-null   object
# dtypes: float64(15), object(21)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Split

# %%
data_size2 = len(data2)
ratio2 = 0.7
pointer = int(ratio2 * data_size2)
train_set2 = data2.iloc[:pointer, :-2]
test_set2 = data2.iloc[pointer:, :-2]
train_dose2 = data2.iloc[:pointer, -1:].values
test_dose2 = data2.iloc[pointer:, -1:].values

# %% [markdown]
# ### Train

# %%
arms = np.arange(12)
accuracy2 = []
A_map2 = {}
b_map2 = {}
for arm in arms:
    A_map2[arm] = np.identity(len(list(train_set2)))
    b_map2[arm] = np.zeros(len(list(train_set2)))

for epoch in range(200):
    start_time = time.time()
    # train
    indices = np.random.permutation(list(range(len(train_set2))))
    for i in indices:
        feature = np.array(train_set2.iloc[i], dtype=float)
        # iterate through actions
        p = {}
        max_value = -np.inf
        max_arm = 0
        for arm in arms:
            theta = np.matmul(np.linalg.inv(A_map2[arm]), b_map2[arm])
            p = np.matmul(theta.T, feature) + \
                np.sqrt(np.matmul(np.matmul(feature.T, np.linalg.inv(A_map2[arm])), feature))

            if p == max_value:
                if np.random.choice(a=[False, True]): max_arm = arm
            elif p > max_value:
                max_value = p
                max_arm = arm

        # observe reward and update A and b
        r = -abs(train_dose2[i][0]-max_arm)
        A_map2[max_arm] += np.outer(feature, feature)
        b_map2[max_arm] += r * feature

    # test
    correct_count = 0
    count = 0
    higher = 0
    lower = 0
    for i in range(len(test_set2)):
        count += 1
        feature = np.array(test_set2.iloc[i], dtype=float)
        # iterate through actions
        p = {}
        max_value = -np.inf
        max_arm = 0
        for arm in arms:
            theta = np.matmul(np.linalg.inv(A_map2[arm]), b_map2[arm])
            p = np.matmul(theta.T, feature) + \
                np.sqrt(np.matmul(np.matmul(feature.T, np.linalg.inv(A_map2[arm])), feature))
            if p == max_value:
                if np.random.choice(a=[False, True]): max_arm = arm
            elif p > max_value:
                max_value = p
                max_arm = arm

        if max_arm == test_dose2[i]:
            correct_count += 1
        elif max_arm < test_dose2[i]:
            lower += test_dose2[i] - max_arm
        else:
            higher += max_arm - test_dose2[i]

    end_time = time.time()
    accu = correct_count / count
    print("Epoch %d: Accuracy: %.5f%% (%d/%d), Higher: %d, Lower: %d, Time: %.5fs" % (
        epoch, accu * 100, correct_count, count, higher, lower, end_time - start_time))
    accuracy2.append(accu)
# Out:
# Epoch 0: Accuracy: 20.83712% (229/1099), Higher: 955, Lower: 846, Time: 2.82148s
# Epoch 1: Accuracy: 20.47316% (225/1099), Higher: 1190, Lower: 741, Time: 2.78803s
# Epoch 2: Accuracy: 19.19927% (211/1099), Higher: 1255, Lower: 713, Time: 2.86258s
# Epoch 3: Accuracy: 19.74522% (217/1099), Higher: 1274, Lower: 702, Time: 2.84646s
# Epoch 4: Accuracy: 19.47225% (214/1099), Higher: 1314, Lower: 698, Time: 2.87059s
# Epoch 5: Accuracy: 19.83621% (218/1099), Higher: 1240, Lower: 671, Time: 2.84085s
# Epoch 6: Accuracy: 20.20018% (222/1099), Higher: 1209, Lower: 680, Time: 2.83575s
# Epoch 7: Accuracy: 19.38126% (213/1099), Higher: 1226, Lower: 679, Time: 2.84125s
# Epoch 8: Accuracy: 20.01820% (220/1099), Higher: 1216, Lower: 674, Time: 2.97593s
# Epoch 9: Accuracy: 19.29026% (212/1099), Higher: 1215, Lower: 687, Time: 2.84880s
# Epoch 10: Accuracy: 18.56233% (204/1099), Higher: 1245, Lower: 681, Time: 2.83153s
# Epoch 11: Accuracy: 18.65332% (205/1099), Higher: 1258, Lower: 675, Time: 2.82825s
# Epoch 12: Accuracy: 19.29026% (212/1099), Higher: 1253, Lower: 662, Time: 2.83378s
# Epoch 13: Accuracy: 18.83530% (207/1099), Higher: 1258, Lower: 667, Time: 2.86206s
# Epoch 14: Accuracy: 19.10828% (210/1099), Higher: 1253, Lower: 662, Time: 2.85780s
# Epoch 15: Accuracy: 18.92630% (208/1099), Higher: 1267, Lower: 657, Time: 2.84146s
# Epoch 16: Accuracy: 18.92630% (208/1099), Higher: 1258, Lower: 675, Time: 2.84566s
# Epoch 17: Accuracy: 19.29026% (212/1099), Higher: 1261, Lower: 669, Time: 2.95735s
# Epoch 18: Accuracy: 19.10828% (210/1099), Higher: 1260, Lower: 675, Time: 2.88037s
# Epoch 19: Accuracy: 19.10828% (210/1099), Higher: 1258, Lower: 675, Time: 2.84825s
# Epoch 20: Accuracy: 19.01729% (209/1099), Higher: 1257, Lower: 679, Time: 2.86745s
# Epoch 21: Accuracy: 19.29026% (212/1099), Higher: 1245, Lower: 682, Time: 2.85077s
# Epoch 22: Accuracy: 19.10828% (210/1099), Higher: 1254, Lower: 676, Time: 2.84957s
# Epoch 23: Accuracy: 19.01729% (209/1099), Higher: 1253, Lower: 682, Time: 2.84403s
# Epoch 24: Accuracy: 19.01729% (209/1099), Higher: 1253, Lower: 689, Time: 2.87747s
# Epoch 25: Accuracy: 18.83530% (207/1099), Higher: 1251, Lower: 693, Time: 2.85943s
# Epoch 26: Accuracy: 19.01729% (209/1099), Higher: 1253, Lower: 693, Time: 2.92303s
# Epoch 27: Accuracy: 19.10828% (210/1099), Higher: 1259, Lower: 685, Time: 2.85331s
# Epoch 28: Accuracy: 19.10828% (210/1099), Higher: 1260, Lower: 682, Time: 2.87663s
# Epoch 29: Accuracy: 19.19927% (211/1099), Higher: 1260, Lower: 679, Time: 2.94106s
# Epoch 30: Accuracy: 19.38126% (213/1099), Higher: 1256, Lower: 680, Time: 2.83922s
# Epoch 31: Accuracy: 19.19927% (211/1099), Higher: 1251, Lower: 683, Time: 2.90602s
# Epoch 32: Accuracy: 19.38126% (213/1099), Higher: 1248, Lower: 676, Time: 3.00099s
# Epoch 33: Accuracy: 19.29026% (212/1099), Higher: 1255, Lower: 676, Time: 2.91730s
# Epoch 34: Accuracy: 19.10828% (210/1099), Higher: 1259, Lower: 677, Time: 2.83418s
# Epoch 35: Accuracy: 19.38126% (213/1099), Higher: 1261, Lower: 673, Time: 2.83491s
# Epoch 36: Accuracy: 19.38126% (213/1099), Higher: 1258, Lower: 677, Time: 2.84161s
# Epoch 37: Accuracy: 19.10828% (210/1099), Higher: 1261, Lower: 679, Time: 2.84803s
# Epoch 38: Accuracy: 18.92630% (208/1099), Higher: 1269, Lower: 679, Time: 2.84781s
# Epoch 39: Accuracy: 18.92630% (208/1099), Higher: 1269, Lower: 679, Time: 2.83723s
# Epoch 40: Accuracy: 19.10828% (210/1099), Higher: 1273, Lower: 668, Time: 2.88302s
# Epoch 41: Accuracy: 19.10828% (210/1099), Higher: 1268, Lower: 675, Time: 2.85334s
# Epoch 42: Accuracy: 19.38126% (213/1099), Higher: 1268, Lower: 672, Time: 2.86040s
# Epoch 43: Accuracy: 19.38126% (213/1099), Higher: 1267, Lower: 679, Time: 2.86705s
# Epoch 44: Accuracy: 19.47225% (214/1099), Higher: 1267, Lower: 678, Time: 2.90475s
# Epoch 45: Accuracy: 19.47225% (214/1099), Higher: 1260, Lower: 677, Time: 2.85690s
# Epoch 46: Accuracy: 19.65423% (216/1099), Higher: 1260, Lower: 673, Time: 2.84083s
# Epoch 47: Accuracy: 19.65423% (216/1099), Higher: 1256, Lower: 674, Time: 2.84812s
# Epoch 48: Accuracy: 19.56324% (215/1099), Higher: 1261, Lower: 673, Time: 2.84712s
# Epoch 49: Accuracy: 19.56324% (215/1099), Higher: 1260, Lower: 674, Time: 2.84860s
# Epoch 50: Accuracy: 19.65423% (216/1099), Higher: 1258, Lower: 671, Time: 2.84373s
# Epoch 51: Accuracy: 19.74522% (217/1099), Higher: 1258, Lower: 671, Time: 2.84389s
# Epoch 52: Accuracy: 19.65423% (216/1099), Higher: 1260, Lower: 669, Time: 2.86153s
# Epoch 53: Accuracy: 19.56324% (215/1099), Higher: 1256, Lower: 675, Time: 2.90750s
# Epoch 54: Accuracy: 19.47225% (214/1099), Higher: 1261, Lower: 674, Time: 2.87834s
# Epoch 55: Accuracy: 19.47225% (214/1099), Higher: 1255, Lower: 681, Time: 2.86845s
# Epoch 56: Accuracy: 19.56324% (215/1099), Higher: 1252, Lower: 681, Time: 2.87006s
# Epoch 57: Accuracy: 19.38126% (213/1099), Higher: 1255, Lower: 684, Time: 2.87609s
# Epoch 58: Accuracy: 19.29026% (212/1099), Higher: 1254, Lower: 684, Time: 2.86973s
# Epoch 59: Accuracy: 19.29026% (212/1099), Higher: 1257, Lower: 686, Time: 2.91893s
# Epoch 60: Accuracy: 19.10828% (210/1099), Higher: 1252, Lower: 692, Time: 2.90108s
# Epoch 61: Accuracy: 19.01729% (209/1099), Higher: 1255, Lower: 692, Time: 2.87745s
# Epoch 62: Accuracy: 18.92630% (208/1099), Higher: 1265, Lower: 685, Time: 2.96177s
# Epoch 63: Accuracy: 19.01729% (209/1099), Higher: 1272, Lower: 678, Time: 3.02332s
# Epoch 64: Accuracy: 19.01729% (209/1099), Higher: 1277, Lower: 675, Time: 3.03382s
# Epoch 65: Accuracy: 19.01729% (209/1099), Higher: 1271, Lower: 678, Time: 3.00644s
# Epoch 66: Accuracy: 19.10828% (210/1099), Higher: 1268, Lower: 678, Time: 3.06738s
# Epoch 67: Accuracy: 18.92630% (208/1099), Higher: 1275, Lower: 684, Time: 2.96993s
# Epoch 68: Accuracy: 18.92630% (208/1099), Higher: 1272, Lower: 684, Time: 2.87401s
# Epoch 69: Accuracy: 18.92630% (208/1099), Higher: 1274, Lower: 684, Time: 2.90292s
# Epoch 70: Accuracy: 18.92630% (208/1099), Higher: 1274, Lower: 686, Time: 2.92510s
# Epoch 71: Accuracy: 19.01729% (209/1099), Higher: 1273, Lower: 685, Time: 2.88095s
# Epoch 72: Accuracy: 19.01729% (209/1099), Higher: 1273, Lower: 681, Time: 2.88139s
# Epoch 73: Accuracy: 19.01729% (209/1099), Higher: 1271, Lower: 684, Time: 2.86527s
# Epoch 74: Accuracy: 18.92630% (208/1099), Higher: 1272, Lower: 687, Time: 2.90959s
# Epoch 75: Accuracy: 18.92630% (208/1099), Higher: 1272, Lower: 686, Time: 2.88678s
# Epoch 76: Accuracy: 19.01729% (209/1099), Higher: 1267, Lower: 689, Time: 2.88270s
# Epoch 77: Accuracy: 19.01729% (209/1099), Higher: 1268, Lower: 686, Time: 2.93765s
# Epoch 78: Accuracy: 18.92630% (208/1099), Higher: 1265, Lower: 691, Time: 2.92187s
# Epoch 79: Accuracy: 18.92630% (208/1099), Higher: 1263, Lower: 691, Time: 2.86352s
# Epoch 80: Accuracy: 19.01729% (209/1099), Higher: 1261, Lower: 691, Time: 2.85545s
# Epoch 81: Accuracy: 18.92630% (208/1099), Higher: 1261, Lower: 690, Time: 2.86407s
# Epoch 82: Accuracy: 19.01729% (209/1099), Higher: 1256, Lower: 692, Time: 2.86511s
# Epoch 83: Accuracy: 19.01729% (209/1099), Higher: 1254, Lower: 690, Time: 2.88302s
# Epoch 84: Accuracy: 18.92630% (208/1099), Higher: 1257, Lower: 691, Time: 2.86616s
# Epoch 85: Accuracy: 19.01729% (209/1099), Higher: 1256, Lower: 693, Time: 2.93273s
# Epoch 86: Accuracy: 19.01729% (209/1099), Higher: 1256, Lower: 691, Time: 2.90380s
# Epoch 87: Accuracy: 19.01729% (209/1099), Higher: 1258, Lower: 693, Time: 2.87400s
# Epoch 88: Accuracy: 19.10828% (210/1099), Higher: 1259, Lower: 691, Time: 2.90432s
# Epoch 89: Accuracy: 19.10828% (210/1099), Higher: 1254, Lower: 693, Time: 2.88937s
# Epoch 90: Accuracy: 19.01729% (209/1099), Higher: 1259, Lower: 689, Time: 2.88118s
# Epoch 91: Accuracy: 19.01729% (209/1099), Higher: 1259, Lower: 691, Time: 2.88111s
# Epoch 92: Accuracy: 19.10828% (210/1099), Higher: 1260, Lower: 688, Time: 3.01276s
# Epoch 93: Accuracy: 19.10828% (210/1099), Higher: 1265, Lower: 688, Time: 2.88739s
# Epoch 94: Accuracy: 19.19927% (211/1099), Higher: 1263, Lower: 689, Time: 2.89258s
# Epoch 95: Accuracy: 19.19927% (211/1099), Higher: 1261, Lower: 690, Time: 2.90280s
# Epoch 96: Accuracy: 19.19927% (211/1099), Higher: 1264, Lower: 690, Time: 2.90850s
# Epoch 97: Accuracy: 19.19927% (211/1099), Higher: 1263, Lower: 693, Time: 2.88319s
# Epoch 98: Accuracy: 19.19927% (211/1099), Higher: 1271, Lower: 680, Time: 2.91204s
# Epoch 99: Accuracy: 19.29026% (212/1099), Higher: 1274, Lower: 677, Time: 2.88617s
# Epoch 100: Accuracy: 19.10828% (210/1099), Higher: 1277, Lower: 677, Time: 2.88830s
# Epoch 101: Accuracy: 19.10828% (210/1099), Higher: 1277, Lower: 675, Time: 2.95110s
# Epoch 102: Accuracy: 19.01729% (209/1099), Higher: 1273, Lower: 681, Time: 2.95457s
# Epoch 103: Accuracy: 19.10828% (210/1099), Higher: 1270, Lower: 680, Time: 2.87987s
# Epoch 104: Accuracy: 19.19927% (211/1099), Higher: 1270, Lower: 679, Time: 2.86452s
# Epoch 105: Accuracy: 19.19927% (211/1099), Higher: 1272, Lower: 679, Time: 2.84538s
# Epoch 106: Accuracy: 19.19927% (211/1099), Higher: 1274, Lower: 676, Time: 2.83289s
# Epoch 107: Accuracy: 19.01729% (209/1099), Higher: 1275, Lower: 682, Time: 2.84277s
# Epoch 108: Accuracy: 19.10828% (210/1099), Higher: 1278, Lower: 677, Time: 2.84373s
# Epoch 109: Accuracy: 19.10828% (210/1099), Higher: 1273, Lower: 676, Time: 2.84910s
# Epoch 110: Accuracy: 19.10828% (210/1099), Higher: 1279, Lower: 676, Time: 2.86828s
# Epoch 111: Accuracy: 19.29026% (212/1099), Higher: 1283, Lower: 673, Time: 2.84529s
# Epoch 112: Accuracy: 19.19927% (211/1099), Higher: 1281, Lower: 675, Time: 2.84794s
# Epoch 113: Accuracy: 19.29026% (212/1099), Higher: 1281, Lower: 673, Time: 2.84291s
# Epoch 114: Accuracy: 19.29026% (212/1099), Higher: 1281, Lower: 672, Time: 2.96605s
# Epoch 115: Accuracy: 19.19927% (211/1099), Higher: 1281, Lower: 673, Time: 2.88075s
# Epoch 116: Accuracy: 19.29026% (212/1099), Higher: 1284, Lower: 671, Time: 2.86774s
# Epoch 117: Accuracy: 19.38126% (213/1099), Higher: 1284, Lower: 669, Time: 2.85869s
# Epoch 118: Accuracy: 19.29026% (212/1099), Higher: 1286, Lower: 669, Time: 2.94973s
# Epoch 119: Accuracy: 19.29026% (212/1099), Higher: 1283, Lower: 668, Time: 2.87761s
# Epoch 120: Accuracy: 19.29026% (212/1099), Higher: 1281, Lower: 669, Time: 2.86264s
# Epoch 121: Accuracy: 19.29026% (212/1099), Higher: 1278, Lower: 669, Time: 2.85799s
# Epoch 122: Accuracy: 19.47225% (214/1099), Higher: 1275, Lower: 669, Time: 2.87461s
# Epoch 123: Accuracy: 19.56324% (215/1099), Higher: 1275, Lower: 668, Time: 2.86307s
# Epoch 124: Accuracy: 19.38126% (213/1099), Higher: 1280, Lower: 670, Time: 2.88419s
# Epoch 125: Accuracy: 19.47225% (214/1099), Higher: 1276, Lower: 669, Time: 3.03546s
# Epoch 126: Accuracy: 19.38126% (213/1099), Higher: 1277, Lower: 669, Time: 3.06026s
# Epoch 127: Accuracy: 19.47225% (214/1099), Higher: 1276, Lower: 669, Time: 3.10301s
# Epoch 128: Accuracy: 19.56324% (215/1099), Higher: 1279, Lower: 665, Time: 3.00607s
# Epoch 129: Accuracy: 19.47225% (214/1099), Higher: 1280, Lower: 667, Time: 2.87165s
# Epoch 130: Accuracy: 19.47225% (214/1099), Higher: 1280, Lower: 667, Time: 2.89633s
# Epoch 131: Accuracy: 19.38126% (213/1099), Higher: 1275, Lower: 670, Time: 2.88954s
# Epoch 132: Accuracy: 19.47225% (214/1099), Higher: 1278, Lower: 668, Time: 2.98963s
# Epoch 133: Accuracy: 19.38126% (213/1099), Higher: 1276, Lower: 670, Time: 2.86782s
# Epoch 134: Accuracy: 19.38126% (213/1099), Higher: 1275, Lower: 671, Time: 2.88372s
# Epoch 135: Accuracy: 19.47225% (214/1099), Higher: 1277, Lower: 668, Time: 2.87670s
# Epoch 136: Accuracy: 19.47225% (214/1099), Higher: 1275, Lower: 668, Time: 2.88957s
# Epoch 137: Accuracy: 19.38126% (213/1099), Higher: 1273, Lower: 669, Time: 3.01962s
# Epoch 138: Accuracy: 19.38126% (213/1099), Higher: 1271, Lower: 670, Time: 2.88934s
# Epoch 139: Accuracy: 19.38126% (213/1099), Higher: 1270, Lower: 671, Time: 2.87265s
# Epoch 140: Accuracy: 19.38126% (213/1099), Higher: 1268, Lower: 672, Time: 2.98893s
# Epoch 141: Accuracy: 19.47225% (214/1099), Higher: 1268, Lower: 671, Time: 2.96569s
# Epoch 142: Accuracy: 19.47225% (214/1099), Higher: 1266, Lower: 671, Time: 2.87037s
# Epoch 143: Accuracy: 19.47225% (214/1099), Higher: 1266, Lower: 671, Time: 2.88405s
# Epoch 144: Accuracy: 19.29026% (212/1099), Higher: 1267, Lower: 676, Time: 2.93814s
# Epoch 145: Accuracy: 19.29026% (212/1099), Higher: 1260, Lower: 677, Time: 2.85972s
# Epoch 146: Accuracy: 19.38126% (213/1099), Higher: 1263, Lower: 676, Time: 2.87274s
# Epoch 147: Accuracy: 19.29026% (212/1099), Higher: 1263, Lower: 678, Time: 2.86589s
# Epoch 148: Accuracy: 19.29026% (212/1099), Higher: 1262, Lower: 680, Time: 2.86521s
# Epoch 149: Accuracy: 19.29026% (212/1099), Higher: 1266, Lower: 677, Time: 2.87096s
# Epoch 150: Accuracy: 19.29026% (212/1099), Higher: 1261, Lower: 683, Time: 2.86288s
# Epoch 151: Accuracy: 19.38126% (213/1099), Higher: 1258, Lower: 683, Time: 2.88427s
# Epoch 152: Accuracy: 19.38126% (213/1099), Higher: 1257, Lower: 680, Time: 2.87574s
# Epoch 153: Accuracy: 19.29026% (212/1099), Higher: 1266, Lower: 680, Time: 2.88807s
# Epoch 154: Accuracy: 19.47225% (214/1099), Higher: 1263, Lower: 679, Time: 2.87505s
# Epoch 155: Accuracy: 19.29026% (212/1099), Higher: 1266, Lower: 680, Time: 2.98475s
# Epoch 156: Accuracy: 19.29026% (212/1099), Higher: 1266, Lower: 683, Time: 2.88557s
# Epoch 157: Accuracy: 19.29026% (212/1099), Higher: 1271, Lower: 683, Time: 2.96544s
# Epoch 158: Accuracy: 19.38126% (213/1099), Higher: 1262, Lower: 685, Time: 2.97970s
# Epoch 159: Accuracy: 19.38126% (213/1099), Higher: 1261, Lower: 685, Time: 2.87973s
# Epoch 160: Accuracy: 19.47225% (214/1099), Higher: 1263, Lower: 683, Time: 2.88396s
# Epoch 161: Accuracy: 19.47225% (214/1099), Higher: 1260, Lower: 685, Time: 2.88188s
# Epoch 162: Accuracy: 19.47225% (214/1099), Higher: 1260, Lower: 685, Time: 2.87791s
# Epoch 163: Accuracy: 19.47225% (214/1099), Higher: 1264, Lower: 685, Time: 3.07832s
# Epoch 164: Accuracy: 19.47225% (214/1099), Higher: 1263, Lower: 685, Time: 3.00211s
# Epoch 165: Accuracy: 19.38126% (213/1099), Higher: 1273, Lower: 684, Time: 2.87380s
# Epoch 166: Accuracy: 19.38126% (213/1099), Higher: 1266, Lower: 684, Time: 3.00614s
# Epoch 167: Accuracy: 19.47225% (214/1099), Higher: 1266, Lower: 684, Time: 2.87776s
# Epoch 168: Accuracy: 19.47225% (214/1099), Higher: 1266, Lower: 684, Time: 2.88373s
# Epoch 169: Accuracy: 19.47225% (214/1099), Higher: 1266, Lower: 684, Time: 2.87859s
# Epoch 170: Accuracy: 19.47225% (214/1099), Higher: 1265, Lower: 686, Time: 2.87507s
# Epoch 171: Accuracy: 19.47225% (214/1099), Higher: 1262, Lower: 685, Time: 2.95133s
# Epoch 172: Accuracy: 19.47225% (214/1099), Higher: 1260, Lower: 686, Time: 2.85062s
# Epoch 173: Accuracy: 19.47225% (214/1099), Higher: 1260, Lower: 686, Time: 2.86655s
# Epoch 174: Accuracy: 19.47225% (214/1099), Higher: 1260, Lower: 686, Time: 2.90193s
# Epoch 175: Accuracy: 19.47225% (214/1099), Higher: 1260, Lower: 686, Time: 2.94481s
# Epoch 176: Accuracy: 19.47225% (214/1099), Higher: 1268, Lower: 683, Time: 2.86926s
# Epoch 177: Accuracy: 19.47225% (214/1099), Higher: 1268, Lower: 683, Time: 2.86041s
# Epoch 178: Accuracy: 19.47225% (214/1099), Higher: 1268, Lower: 683, Time: 2.92828s
# Epoch 179: Accuracy: 19.47225% (214/1099), Higher: 1271, Lower: 683, Time: 2.86640s
# Epoch 180: Accuracy: 19.47225% (214/1099), Higher: 1269, Lower: 684, Time: 3.00523s
# Epoch 181: Accuracy: 19.47225% (214/1099), Higher: 1277, Lower: 680, Time: 2.87012s
# Epoch 182: Accuracy: 19.47225% (214/1099), Higher: 1276, Lower: 680, Time: 2.85487s
# Epoch 183: Accuracy: 19.47225% (214/1099), Higher: 1276, Lower: 680, Time: 2.85836s
# Epoch 184: Accuracy: 19.47225% (214/1099), Higher: 1276, Lower: 684, Time: 2.84606s
# Epoch 185: Accuracy: 19.47225% (214/1099), Higher: 1276, Lower: 684, Time: 2.85333s
# Epoch 186: Accuracy: 19.47225% (214/1099), Higher: 1275, Lower: 684, Time: 2.97097s
# Epoch 187: Accuracy: 19.47225% (214/1099), Higher: 1275, Lower: 685, Time: 3.02658s
# Epoch 188: Accuracy: 19.47225% (214/1099), Higher: 1275, Lower: 685, Time: 2.90881s
# Epoch 189: Accuracy: 19.47225% (214/1099), Higher: 1277, Lower: 682, Time: 2.83757s
# Epoch 190: Accuracy: 19.47225% (214/1099), Higher: 1277, Lower: 682, Time: 2.89103s
# Epoch 191: Accuracy: 19.47225% (214/1099), Higher: 1262, Lower: 691, Time: 2.87806s
# Epoch 192: Accuracy: 19.47225% (214/1099), Higher: 1265, Lower: 688, Time: 2.91426s
# Epoch 193: Accuracy: 19.47225% (214/1099), Higher: 1265, Lower: 688, Time: 2.95371s
# Epoch 194: Accuracy: 19.47225% (214/1099), Higher: 1265, Lower: 688, Time: 3.05732s
# Epoch 195: Accuracy: 19.47225% (214/1099), Higher: 1265, Lower: 688, Time: 3.02469s
# Epoch 196: Accuracy: 19.47225% (214/1099), Higher: 1268, Lower: 688, Time: 2.87673s
# Epoch 197: Accuracy: 19.47225% (214/1099), Higher: 1268, Lower: 688, Time: 2.98867s
# Epoch 198: Accuracy: 19.47225% (214/1099), Higher: 1264, Lower: 688, Time: 2.94817s
# Epoch 199: Accuracy: 19.38126% (213/1099), Higher: 1265, Lower: 688, Time: 2.94579s

# %%
plt.plot(accuracy2)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# ### Validate

# %%
val_set2 = data2.iloc[:, :-2]
val_dose2 = data2.iloc[:, -1:].values

# %%
arms = np.arange(12)
correct_count = 0
count = 0
heatmap2 = np.zeros((12, 12))

for i in range(len(data2)):
    count += 1
    feature = np.array(val_set2.iloc[i], dtype=float)
    # iterate through actions
    p = {}
    max_value = -np.inf
    max_arm = 0
    for arm in arms:
        theta = np.matmul(np.linalg.inv(A_map2[arm]), b_map2[arm])
        p = np.matmul(theta.T, feature) + \
            np.sqrt(np.matmul(np.matmul(feature.T, np.linalg.inv(A_map2[arm])), feature))
        if p == max_value:
            if np.random.choice(a=[False, True]): max_arm = arm
        elif p > max_value:
            max_value = p
            max_arm = arm

    if max_arm == val_dose2[i][0]:
        correct_count += 1
    heatmap2[max_arm][int(val_dose2[i][0])] += 1

accu = correct_count / count
print("Validate: Accuracy: %.5f%% (%d/%d)" % (accu * 100, correct_count, count))
# Out:
# Validate: Accuracy: 27.43653% (1005/3663)

# %%
ax = sns.heatmap(heatmap2, linewidth=0.5, annot=True, cmap='Blues', fmt='.20g')
plt.show()

# %% [markdown]
# ## Long range
# ### Filter

# %%
data3 = data2.copy()
data3.loc[data3['dose'] < 21,'type'] = 0
data3.loc[(data3['dose'] >= 21) & (data3['dose'] < 49),'type'] = 1
data3.loc[data3['dose'] >= 49,'type'] = 2

# %% [markdown]
# ### Split

# %%
data_size3 = len(data3)
ratio3 = 0.7
pointer = int(ratio3 * data_size3)
train_set3 = data3.iloc[:pointer, :-2]
test_set3 = data3.iloc[pointer:, :-2]
train_dose3 = data3.iloc[:pointer, -1:].values
test_dose3 = data3.iloc[pointer:, -1:].values

# %% [markdown]
# ### Train

# %%
arms = np.arange(3)
accuracy3 = []
A_map3 = {}
b_map3 = {}
for arm in arms:
    A_map3[arm] = np.identity(len(list(train_set3)))
    b_map3[arm] = np.zeros(len(list(train_set3)))

for epoch in range(200):
    start_time = time.time()
    # train
    indices = np.random.permutation(list(range(len(train_set3))))
    for i in indices:
        feature = np.array(train_set3.iloc[i], dtype=float)
        # iterate through actions
        p = {}
        max_value = -np.inf
        max_arm = 0
        for arm in arms:
            theta = np.matmul(np.linalg.inv(A_map3[arm]), b_map3[arm])
            p = np.matmul(theta.T, feature) + \
                np.sqrt(np.matmul(np.matmul(feature.T, np.linalg.inv(A_map3[arm])), feature))

            if p == max_value:
                if np.random.choice(a=[False, True]): max_arm = arm
            elif p > max_value:
                max_value = p
                max_arm = arm

        # observe reward and update A and b
        r = -abs(train_dose3[i][0]-max_arm)
        A_map3[max_arm] += np.outer(feature, feature)
        b_map3[max_arm] += r * feature

    # test
    correct_count = 0
    count = 0
    higher = 0
    lower = 0
    for i in range(len(test_set3)):
        count += 1
        feature = np.array(test_set3.iloc[i], dtype=float)
        # iterate through actions
        p = {}
        max_value = -np.inf
        max_arm = 0
        for arm in arms:
            theta = np.matmul(np.linalg.inv(A_map3[arm]), b_map3[arm])
            p = np.matmul(theta.T, feature) + \
                np.sqrt(np.matmul(np.matmul(feature.T, np.linalg.inv(A_map3[arm])), feature))
            if p == max_value:
                if np.random.choice(a=[False, True]): max_arm = arm
            elif p > max_value:
                max_value = p
                max_arm = arm

        if max_arm == test_dose3[i]:
            correct_count += 1
        elif max_arm < test_dose3[i]:
            lower += test_dose3[i] - max_arm
        else:
            higher += max_arm - test_dose3[i]

    end_time = time.time()
    accu = correct_count / count
    print("Epoch %d: Accuracy: %.5f%% (%d/%d), Higher: %d, Lower: %d, Time: %.5fs" % (
        epoch, accu * 100, correct_count, count, higher, lower, end_time - start_time))
    accuracy3.append(accu)
# Out:
# Epoch 0: Accuracy: 63.51228% (698/1099), Higher: 221, Lower: 186, Time: 1.08340s
# Epoch 1: Accuracy: 65.33212% (718/1099), Higher: 209, Lower: 178, Time: 1.03576s
# Epoch 2: Accuracy: 65.69609% (722/1099), Higher: 196, Lower: 185, Time: 1.06853s
# Epoch 3: Accuracy: 65.69609% (722/1099), Higher: 193, Lower: 188, Time: 1.08547s
# Epoch 4: Accuracy: 66.33303% (729/1099), Higher: 190, Lower: 185, Time: 1.05725s
# Epoch 5: Accuracy: 66.06005% (726/1099), Higher: 187, Lower: 191, Time: 1.11316s
# Epoch 6: Accuracy: 66.24204% (728/1099), Higher: 188, Lower: 188, Time: 1.04773s
# Epoch 7: Accuracy: 66.33303% (729/1099), Higher: 185, Lower: 190, Time: 1.06116s
# Epoch 8: Accuracy: 66.06005% (726/1099), Higher: 183, Lower: 195, Time: 1.05507s
# Epoch 9: Accuracy: 66.06005% (726/1099), Higher: 185, Lower: 193, Time: 1.12219s
# Epoch 10: Accuracy: 66.33303% (729/1099), Higher: 183, Lower: 192, Time: 1.06779s
# Epoch 11: Accuracy: 66.87898% (735/1099), Higher: 179, Lower: 191, Time: 1.08927s
# Epoch 12: Accuracy: 66.51501% (731/1099), Higher: 182, Lower: 191, Time: 1.03127s
# Epoch 13: Accuracy: 66.69700% (733/1099), Higher: 181, Lower: 190, Time: 1.06722s
# Epoch 14: Accuracy: 66.60601% (732/1099), Higher: 184, Lower: 189, Time: 1.03318s
# Epoch 15: Accuracy: 66.51501% (731/1099), Higher: 182, Lower: 191, Time: 1.05835s
# Epoch 16: Accuracy: 66.42402% (730/1099), Higher: 183, Lower: 191, Time: 1.01472s
# Epoch 17: Accuracy: 66.60601% (732/1099), Higher: 181, Lower: 191, Time: 1.01385s
# Epoch 18: Accuracy: 66.51501% (731/1099), Higher: 183, Lower: 190, Time: 1.00960s
# Epoch 19: Accuracy: 66.42402% (730/1099), Higher: 183, Lower: 191, Time: 1.00960s
# Epoch 20: Accuracy: 66.51501% (731/1099), Higher: 181, Lower: 192, Time: 1.03225s
# Epoch 21: Accuracy: 66.51501% (731/1099), Higher: 181, Lower: 192, Time: 1.08271s
# Epoch 22: Accuracy: 66.60601% (732/1099), Higher: 183, Lower: 189, Time: 1.09915s
# Epoch 23: Accuracy: 66.69700% (733/1099), Higher: 182, Lower: 189, Time: 1.03054s
# Epoch 24: Accuracy: 66.60601% (732/1099), Higher: 182, Lower: 191, Time: 1.03926s
# Epoch 25: Accuracy: 66.42402% (730/1099), Higher: 184, Lower: 190, Time: 1.01712s
# Epoch 26: Accuracy: 66.60601% (732/1099), Higher: 185, Lower: 188, Time: 1.06717s
# Epoch 27: Accuracy: 66.60601% (732/1099), Higher: 185, Lower: 188, Time: 1.08566s
# Epoch 28: Accuracy: 66.51501% (731/1099), Higher: 185, Lower: 189, Time: 1.00999s
# Epoch 29: Accuracy: 66.60601% (732/1099), Higher: 186, Lower: 187, Time: 1.00425s
# Epoch 30: Accuracy: 66.69700% (733/1099), Higher: 185, Lower: 187, Time: 1.01000s
# Epoch 31: Accuracy: 66.51501% (731/1099), Higher: 183, Lower: 191, Time: 1.00928s
# Epoch 32: Accuracy: 66.33303% (729/1099), Higher: 185, Lower: 191, Time: 1.00549s
# Epoch 33: Accuracy: 66.33303% (729/1099), Higher: 186, Lower: 190, Time: 1.02162s
# Epoch 34: Accuracy: 66.51501% (731/1099), Higher: 185, Lower: 189, Time: 1.01084s
# Epoch 35: Accuracy: 66.42402% (730/1099), Higher: 186, Lower: 189, Time: 1.01288s
# Epoch 36: Accuracy: 66.33303% (729/1099), Higher: 186, Lower: 190, Time: 1.01147s
# Epoch 37: Accuracy: 66.33303% (729/1099), Higher: 186, Lower: 190, Time: 1.06699s
# Epoch 38: Accuracy: 66.24204% (728/1099), Higher: 186, Lower: 191, Time: 1.07571s
# Epoch 39: Accuracy: 66.24204% (728/1099), Higher: 186, Lower: 191, Time: 1.00806s
# Epoch 40: Accuracy: 66.33303% (729/1099), Higher: 186, Lower: 190, Time: 1.00632s
# Epoch 41: Accuracy: 66.33303% (729/1099), Higher: 186, Lower: 190, Time: 1.01313s
# Epoch 42: Accuracy: 66.24204% (728/1099), Higher: 186, Lower: 191, Time: 1.00662s
# Epoch 43: Accuracy: 66.33303% (729/1099), Higher: 187, Lower: 189, Time: 1.00067s
# Epoch 44: Accuracy: 66.60601% (732/1099), Higher: 186, Lower: 187, Time: 1.00944s
# Epoch 45: Accuracy: 66.51501% (731/1099), Higher: 187, Lower: 187, Time: 1.00382s
# Epoch 46: Accuracy: 66.51501% (731/1099), Higher: 187, Lower: 187, Time: 1.08333s
# Epoch 47: Accuracy: 66.60601% (732/1099), Higher: 187, Lower: 186, Time: 1.02731s
# Epoch 48: Accuracy: 66.51501% (731/1099), Higher: 187, Lower: 187, Time: 1.01292s
# Epoch 49: Accuracy: 66.60601% (732/1099), Higher: 187, Lower: 186, Time: 1.15195s
# Epoch 50: Accuracy: 66.60601% (732/1099), Higher: 187, Lower: 186, Time: 1.01810s
# Epoch 51: Accuracy: 66.51501% (731/1099), Higher: 187, Lower: 187, Time: 1.00981s
# Epoch 52: Accuracy: 66.51501% (731/1099), Higher: 187, Lower: 187, Time: 1.01299s
# Epoch 53: Accuracy: 66.51501% (731/1099), Higher: 187, Lower: 187, Time: 1.01383s
# Epoch 54: Accuracy: 66.60601% (732/1099), Higher: 187, Lower: 186, Time: 1.02797s
# Epoch 55: Accuracy: 66.60601% (732/1099), Higher: 188, Lower: 185, Time: 1.01302s
# Epoch 56: Accuracy: 66.60601% (732/1099), Higher: 187, Lower: 186, Time: 1.02423s
# Epoch 57: Accuracy: 66.51501% (731/1099), Higher: 188, Lower: 186, Time: 1.04080s
# Epoch 58: Accuracy: 66.60601% (732/1099), Higher: 187, Lower: 186, Time: 1.07112s
# Epoch 59: Accuracy: 66.69700% (733/1099), Higher: 187, Lower: 185, Time: 1.02469s
# Epoch 60: Accuracy: 66.51501% (731/1099), Higher: 188, Lower: 186, Time: 1.07497s
# Epoch 61: Accuracy: 66.51501% (731/1099), Higher: 188, Lower: 186, Time: 1.04949s
# Epoch 62: Accuracy: 66.51501% (731/1099), Higher: 188, Lower: 186, Time: 1.02109s
# Epoch 63: Accuracy: 66.60601% (732/1099), Higher: 188, Lower: 185, Time: 1.01700s
# Epoch 64: Accuracy: 66.51501% (731/1099), Higher: 188, Lower: 186, Time: 1.04322s
# Epoch 65: Accuracy: 66.51501% (731/1099), Higher: 188, Lower: 186, Time: 1.00980s
# Epoch 66: Accuracy: 66.69700% (733/1099), Higher: 188, Lower: 184, Time: 1.00937s
# Epoch 67: Accuracy: 66.69700% (733/1099), Higher: 188, Lower: 184, Time: 1.00688s
# Epoch 68: Accuracy: 66.69700% (733/1099), Higher: 188, Lower: 184, Time: 1.01050s
# Epoch 69: Accuracy: 66.60601% (732/1099), Higher: 188, Lower: 185, Time: 1.01034s
# Epoch 70: Accuracy: 66.60601% (732/1099), Higher: 188, Lower: 185, Time: 1.00361s
# Epoch 71: Accuracy: 66.69700% (733/1099), Higher: 188, Lower: 184, Time: 0.99932s
# Epoch 72: Accuracy: 66.69700% (733/1099), Higher: 188, Lower: 184, Time: 1.02473s
# Epoch 73: Accuracy: 66.60601% (732/1099), Higher: 188, Lower: 185, Time: 1.06107s
# Epoch 74: Accuracy: 66.60601% (732/1099), Higher: 188, Lower: 185, Time: 1.05806s
# Epoch 75: Accuracy: 66.78799% (734/1099), Higher: 187, Lower: 184, Time: 1.02823s
# Epoch 76: Accuracy: 66.78799% (734/1099), Higher: 187, Lower: 184, Time: 1.02974s
# Epoch 77: Accuracy: 66.69700% (733/1099), Higher: 188, Lower: 184, Time: 1.00013s
# Epoch 78: Accuracy: 66.69700% (733/1099), Higher: 188, Lower: 184, Time: 1.00111s
# Epoch 79: Accuracy: 66.60601% (732/1099), Higher: 189, Lower: 184, Time: 1.00276s
# Epoch 80: Accuracy: 66.69700% (733/1099), Higher: 188, Lower: 184, Time: 0.99562s
# Epoch 81: Accuracy: 66.69700% (733/1099), Higher: 188, Lower: 184, Time: 0.99824s
# Epoch 82: Accuracy: 66.60601% (732/1099), Higher: 189, Lower: 184, Time: 0.99681s
# Epoch 83: Accuracy: 66.60601% (732/1099), Higher: 189, Lower: 184, Time: 1.00047s
# Epoch 84: Accuracy: 66.69700% (733/1099), Higher: 188, Lower: 184, Time: 1.00503s
# Epoch 85: Accuracy: 66.69700% (733/1099), Higher: 188, Lower: 184, Time: 1.00953s
# Epoch 86: Accuracy: 66.60601% (732/1099), Higher: 189, Lower: 184, Time: 1.04086s
# Epoch 87: Accuracy: 66.51501% (731/1099), Higher: 189, Lower: 185, Time: 1.06509s
# Epoch 88: Accuracy: 66.51501% (731/1099), Higher: 190, Lower: 184, Time: 1.01633s
# Epoch 89: Accuracy: 66.42402% (730/1099), Higher: 191, Lower: 184, Time: 1.04439s
# Epoch 90: Accuracy: 66.51501% (731/1099), Higher: 190, Lower: 184, Time: 1.03579s
# Epoch 91: Accuracy: 66.51501% (731/1099), Higher: 190, Lower: 184, Time: 1.00535s
# Epoch 92: Accuracy: 66.42402% (730/1099), Higher: 191, Lower: 184, Time: 1.00232s
# Epoch 93: Accuracy: 66.42402% (730/1099), Higher: 191, Lower: 184, Time: 1.00013s
# Epoch 94: Accuracy: 66.42402% (730/1099), Higher: 191, Lower: 184, Time: 1.03495s
# Epoch 95: Accuracy: 66.42402% (730/1099), Higher: 191, Lower: 184, Time: 1.02262s
# Epoch 96: Accuracy: 66.33303% (729/1099), Higher: 191, Lower: 185, Time: 1.01891s
# Epoch 97: Accuracy: 66.42402% (730/1099), Higher: 191, Lower: 184, Time: 1.01803s
# Epoch 98: Accuracy: 66.42402% (730/1099), Higher: 191, Lower: 184, Time: 1.04277s
# Epoch 99: Accuracy: 66.42402% (730/1099), Higher: 191, Lower: 184, Time: 1.01524s
# Epoch 100: Accuracy: 66.42402% (730/1099), Higher: 191, Lower: 184, Time: 1.01680s
# Epoch 101: Accuracy: 66.42402% (730/1099), Higher: 191, Lower: 184, Time: 1.01381s
# Epoch 102: Accuracy: 66.42402% (730/1099), Higher: 191, Lower: 184, Time: 1.03500s
# Epoch 103: Accuracy: 66.42402% (730/1099), Higher: 191, Lower: 184, Time: 1.07058s
# Epoch 104: Accuracy: 66.42402% (730/1099), Higher: 192, Lower: 183, Time: 1.07453s
# Epoch 105: Accuracy: 66.42402% (730/1099), Higher: 192, Lower: 183, Time: 1.04614s
# Epoch 106: Accuracy: 66.33303% (729/1099), Higher: 192, Lower: 184, Time: 1.03533s
# Epoch 107: Accuracy: 66.33303% (729/1099), Higher: 192, Lower: 184, Time: 1.00089s
# Epoch 108: Accuracy: 66.42402% (730/1099), Higher: 192, Lower: 183, Time: 1.03611s
# Epoch 109: Accuracy: 66.42402% (730/1099), Higher: 192, Lower: 183, Time: 1.01276s
# Epoch 110: Accuracy: 66.33303% (729/1099), Higher: 192, Lower: 184, Time: 1.06532s
# Epoch 111: Accuracy: 66.42402% (730/1099), Higher: 192, Lower: 183, Time: 1.01703s
# Epoch 112: Accuracy: 66.42402% (730/1099), Higher: 192, Lower: 183, Time: 0.99240s
# Epoch 113: Accuracy: 66.42402% (730/1099), Higher: 192, Lower: 183, Time: 0.99436s
# Epoch 114: Accuracy: 66.33303% (729/1099), Higher: 192, Lower: 184, Time: 0.99253s
# Epoch 115: Accuracy: 66.51501% (731/1099), Higher: 192, Lower: 182, Time: 0.99839s
# Epoch 116: Accuracy: 66.42402% (730/1099), Higher: 192, Lower: 183, Time: 1.00113s
# Epoch 117: Accuracy: 66.51501% (731/1099), Higher: 192, Lower: 182, Time: 1.01526s
# Epoch 118: Accuracy: 66.42402% (730/1099), Higher: 192, Lower: 183, Time: 1.08148s
# Epoch 119: Accuracy: 66.51501% (731/1099), Higher: 192, Lower: 182, Time: 1.07484s
# Epoch 120: Accuracy: 66.51501% (731/1099), Higher: 192, Lower: 182, Time: 1.04583s
# Epoch 121: Accuracy: 66.51501% (731/1099), Higher: 192, Lower: 182, Time: 1.03149s
# Epoch 122: Accuracy: 66.42402% (730/1099), Higher: 192, Lower: 183, Time: 1.08291s
# Epoch 123: Accuracy: 66.51501% (731/1099), Higher: 192, Lower: 182, Time: 1.03107s
# Epoch 124: Accuracy: 66.60601% (732/1099), Higher: 192, Lower: 181, Time: 1.03982s
# Epoch 125: Accuracy: 66.51501% (731/1099), Higher: 192, Lower: 182, Time: 1.02823s
# Epoch 126: Accuracy: 66.42402% (730/1099), Higher: 192, Lower: 183, Time: 1.03087s
# Epoch 127: Accuracy: 66.51501% (731/1099), Higher: 192, Lower: 182, Time: 1.03037s
# Epoch 128: Accuracy: 66.42402% (730/1099), Higher: 192, Lower: 183, Time: 1.02591s
# Epoch 129: Accuracy: 66.33303% (729/1099), Higher: 193, Lower: 183, Time: 1.02939s
# Epoch 130: Accuracy: 66.42402% (730/1099), Higher: 193, Lower: 182, Time: 1.02767s
# Epoch 131: Accuracy: 66.33303% (729/1099), Higher: 193, Lower: 183, Time: 1.02737s
# Epoch 132: Accuracy: 66.33303% (729/1099), Higher: 193, Lower: 183, Time: 1.02468s
# Epoch 133: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.06884s
# Epoch 134: Accuracy: 66.33303% (729/1099), Higher: 193, Lower: 183, Time: 1.06754s
# Epoch 135: Accuracy: 66.33303% (729/1099), Higher: 194, Lower: 182, Time: 1.08319s
# Epoch 136: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.08478s
# Epoch 137: Accuracy: 66.33303% (729/1099), Higher: 194, Lower: 182, Time: 1.05637s
# Epoch 138: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.05991s
# Epoch 139: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.05711s
# Epoch 140: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.06534s
# Epoch 141: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02232s
# Epoch 142: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02656s
# Epoch 143: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.04226s
# Epoch 144: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.00718s
# Epoch 145: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01566s
# Epoch 146: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.06225s
# Epoch 147: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.06773s
# Epoch 148: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.06813s
# Epoch 149: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.00225s
# Epoch 150: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.05746s
# Epoch 151: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.04084s
# Epoch 152: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02074s
# Epoch 153: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.04498s
# Epoch 154: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02446s
# Epoch 155: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01905s
# Epoch 156: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02534s
# Epoch 157: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02416s
# Epoch 158: Accuracy: 66.33303% (729/1099), Higher: 193, Lower: 183, Time: 1.02405s
# Epoch 159: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.06979s
# Epoch 160: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02461s
# Epoch 161: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02108s
# Epoch 162: Accuracy: 66.33303% (729/1099), Higher: 193, Lower: 183, Time: 1.02435s
# Epoch 163: Accuracy: 66.33303% (729/1099), Higher: 193, Lower: 183, Time: 1.02459s
# Epoch 164: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01908s
# Epoch 165: Accuracy: 66.33303% (729/1099), Higher: 193, Lower: 183, Time: 1.02398s
# Epoch 166: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01807s
# Epoch 167: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01366s
# Epoch 168: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02031s
# Epoch 169: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02047s
# Epoch 170: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01493s
# Epoch 171: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01855s
# Epoch 172: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02295s
# Epoch 173: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02408s
# Epoch 174: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02630s
# Epoch 175: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01925s
# Epoch 176: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02172s
# Epoch 177: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.03469s
# Epoch 178: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01786s
# Epoch 179: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.03096s
# Epoch 180: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.04244s
# Epoch 181: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.08304s
# Epoch 182: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.08837s
# Epoch 183: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.09359s
# Epoch 184: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.04486s
# Epoch 185: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02141s
# Epoch 186: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01915s
# Epoch 187: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.03021s
# Epoch 188: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.03100s
# Epoch 189: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01869s
# Epoch 190: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.04520s
# Epoch 191: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01774s
# Epoch 192: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01546s
# Epoch 193: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01037s
# Epoch 194: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.04037s
# Epoch 195: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.06274s
# Epoch 196: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.05295s
# Epoch 197: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.02523s
# Epoch 198: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01445s
# Epoch 199: Accuracy: 66.24204% (728/1099), Higher: 194, Lower: 183, Time: 1.01996s

# %%
plt.plot(accuracy3)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# ### Validate

# %%
val_set3 = data3.iloc[:, :-2]
val_dose3 = data3.iloc[:, -1:].values

# %%
arms = np.arange(3)
correct_count = 0
count = 0
heatmap3 = np.zeros((3, 3))

for i in range(len(data3)):
    count += 1
    feature = np.array(val_set3.iloc[i], dtype=float)
    # iterate through actions
    p = {}
    max_value = -np.inf
    max_arm = 0
    for arm in arms:
        theta = np.matmul(np.linalg.inv(A_map3[arm]), b_map3[arm])
        p = np.matmul(theta.T, feature) + \
            np.sqrt(np.matmul(np.matmul(feature.T, np.linalg.inv(A_map3[arm])), feature))
        if p == max_value:
            if np.random.choice(a=[False, True]): max_arm = arm
        elif p > max_value:
            max_value = p
            max_arm = arm

    if max_arm == val_dose3[i][0]:
        correct_count += 1
    heatmap3[max_arm][int(val_dose3[i][0])] += 1

accu = correct_count / count
print("Validate: Accuracy: %.5f%% (%d/%d)" % (accu * 100, correct_count, count))
# Out:
# Validate: Accuracy: 71.17117% (2607/3663)

# %%
ax = sns.heatmap(heatmap3, linewidth=0.5, annot=True, cmap='Blues', fmt='.20g')
plt.show()
